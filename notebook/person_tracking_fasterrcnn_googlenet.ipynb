# %% [markdown]
# ## Download Data

# %%
# !pip install fiftyone
# !pip install fiftyone-db-ubuntu2204
# Out:
# Collecting fiftyone
#   Downloading fiftyone-0.22.3-py3-none-any.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 58.1 MB/s eta 0:00:00
# Collecting aiofiles (from fiftyone)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Collecting argcomplete (from fiftyone)
#   Downloading argcomplete-3.1.6-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from fiftyone) (4.11.2)
# Collecting boto3 (from fiftyone)
#   Downloading boto3-1.33.4-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from fiftyone) (5.3.2)
# Collecting dacite<1.8.0,>=1.6.0 (from fiftyone)
#   Downloading dacite-1.7.0-py3-none-any.whl (12 kB)
# Collecting Deprecated (from fiftyone)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting ftfy (from fiftyone)
#   Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: humanize in /usr/local/lib/python3.10/dist-packages (from fiftyone) (4.7.0)
# Collecting hypercorn>=0.13.2 (from fiftyone)
#   Downloading hypercorn-0.15.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2>=3 in /usr/local/lib/python3.10/dist-packages (from fiftyone) (3.1.2)
# Collecting kaleido!=0.2.1.post1 (from fiftyone)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from fiftyone) (3.7.1)
# Collecting mongoengine==0.24.2 (from fiftyone)
#   Downloading mongoengine-0.24.2-py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 15.2 MB/s eta 0:00:00
# Collecting motor>=2.5 (from fiftyone)
#   Downloading motor-3.3.2-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fiftyone) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fiftyone) (23.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from fiftyone) (1.5.3)
# Requirement already satisfied: Pillow>=6.2 in /usr/local/lib/python3.10/dist-packages (from fiftyone) (9.4.0)
# Requirement already satisfied: plotly>=4.14 in /usr/local/lib/python3.10/dist-packages (from fiftyone) (5.15.0)
# Collecting pprintpp (from fiftyone)
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from fiftyone) (5.9.5)
# Collecting pymongo>=3.12 (from fiftyone)
#   Downloading pymongo-4.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (677 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 27.3 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from fiftyone) (2023.3.post1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from fiftyone) (6.0.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from fiftyone) (2023.6.3)
# Collecting retrying (from fiftyone)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from fiftyone) (1.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from fiftyone) (0.19.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from fiftyone) (67.7.2)
# Collecting sseclient-py<2,>=1.7.2 (from fiftyone)
#   Downloading sseclient_py-1.8.0-py2.py3-none-any.whl (8.8 kB)
# Collecting sse-starlette<1,>=0.10.3 (from fiftyone)
#   Downloading sse_starlette-0.10.3-py3-none-any.whl (8.0 kB)
# Collecting starlette>=0.24.0 (from fiftyone)
#   Downloading starlette-0.32.0.post1-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 8.4 MB/s eta 0:00:00
# Collecting strawberry-graphql==0.138.1 (from fiftyone)
#   Downloading strawberry_graphql-0.138.1-py3-none-any.whl (192 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.5/192.5 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fiftyone) (0.9.0)
# Collecting xmltodict (from fiftyone)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Collecting universal-analytics-python3<2,>=1.0.1 (from fiftyone)
#   Downloading universal_analytics_python3-1.1.1-py3-none-any.whl (10 kB)
# Collecting fiftyone-brain~=0.13.2 (from fiftyone)
#   Downloading fiftyone_brain-0.13.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 11.6 MB/s eta 0:00:00
# Collecting fiftyone-db~=0.4 (from fiftyone)
#   Downloading fiftyone_db-0.4.0-py3-none-manylinux1_x86_64.whl (37.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.8/37.8 MB 33.6 MB/s eta 0:00:00
# Collecting voxel51-eta~=0.12 (from fiftyone)
#   Downloading voxel51_eta-0.12.0-py2.py3-none-any.whl (570 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 52.9 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from fiftyone) (4.8.1.78)
# Collecting graphql-core<3.3.0,>=3.2.0 (from strawberry-graphql==0.138.1->fiftyone)
#   Downloading graphql_core-3.2.3-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 24.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from strawberry-graphql==0.138.1->fiftyone) (2.8.2)
# Requirement already satisfied: typing_extensions<5.0.0,>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from strawberry-graphql==0.138.1->fiftyone) (4.5.0)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from fiftyone-brain~=0.13.2->fiftyone) (1.11.3)
# Collecting h11 (from hypercorn>=0.13.2->fiftyone)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.7 MB/s eta 0:00:00
# Collecting h2>=3.1.0 (from hypercorn>=0.13.2->fiftyone)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 8.6 MB/s eta 0:00:00
# Collecting priority (from hypercorn>=0.13.2->fiftyone)
#   Downloading priority-2.0.0-py3-none-any.whl (8.9 kB)
# Collecting taskgroup (from hypercorn>=0.13.2->fiftyone)
#   Downloading taskgroup-0.0.0a4-py2.py3-none-any.whl (9.1 kB)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from hypercorn>=0.13.2->fiftyone) (2.0.1)
# Collecting wsproto>=0.14.0 (from hypercorn>=0.13.2->fiftyone)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3->fiftyone) (2.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.14->fiftyone) (8.2.3)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo>=3.12->fiftyone)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette>=0.24.0->fiftyone) (3.7.1)
# Collecting httpx>=0.10.0 (from universal-analytics-python3<2,>=1.0.1->fiftyone)
#   Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.2 MB/s eta 0:00:00
# Collecting dill (from voxel51-eta~=0.12->fiftyone)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from voxel51-eta~=0.12->fiftyone) (0.18.3)
# Requirement already satisfied: glob2 in /usr/local/lib/python3.10/dist-packages (from voxel51-eta~=0.12->fiftyone) (0.7)
# Collecting jsonlines (from voxel51-eta~=0.12->fiftyone)
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Collecting py7zr (from voxel51-eta~=0.12->fiftyone)
#   Downloading py7zr-0.20.8-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.4 MB/s eta 0:00:00
# Collecting rarfile (from voxel51-eta~=0.12->fiftyone)
#   Downloading rarfile-4.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from voxel51-eta~=0.12->fiftyone) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from voxel51-eta~=0.12->fiftyone) (1.16.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from voxel51-eta~=0.12->fiftyone) (2.4.0)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from voxel51-eta~=0.12->fiftyone) (5.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from voxel51-eta~=0.12->fiftyone) (2.0.7)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->fiftyone) (2.5)
# Collecting botocore<1.34.0,>=1.33.4 (from boto3->fiftyone)
#   Downloading botocore-1.33.4-py3-none-any.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 104.8 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->fiftyone)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.9.0,>=0.8.2 (from boto3->fiftyone)
#   Downloading s3transfer-0.8.2-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated->fiftyone) (1.14.1)
# Collecting wcwidth<0.3.0,>=0.2.12 (from ftfy->fiftyone)
#   Downloading wcwidth-0.2.12-py2.py3-none-any.whl (34 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fiftyone) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fiftyone) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fiftyone) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fiftyone) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fiftyone) (3.1.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->fiftyone) (3.2.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->fiftyone) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->fiftyone) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->fiftyone) (1.4.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fiftyone) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fiftyone) (3.2.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette>=0.24.0->fiftyone) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette>=0.24.0->fiftyone) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette>=0.24.0->fiftyone) (1.1.3)
# Collecting hyperframe<7,>=6.0 (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (2023.7.22)
# Collecting httpcore==1.* (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->voxel51-eta~=0.12->fiftyone) (23.1.0)
# Collecting texttable (from py7zr->voxel51-eta~=0.12->fiftyone)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting pycryptodomex>=3.16.0 (from py7zr->voxel51-eta~=0.12->fiftyone)
#   Downloading pycryptodomex-3.19.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 92.8 MB/s eta 0:00:00
# Collecting pyzstd>=0.15.9 (from py7zr->voxel51-eta~=0.12->fiftyone)
#   Downloading pyzstd-0.15.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 43.8 MB/s eta 0:00:00
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr->voxel51-eta~=0.12->fiftyone)
#   Downloading pyppmd-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.9/138.9 kB 21.7 MB/s eta 0:00:00
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr->voxel51-eta~=0.12->fiftyone)
#   Downloading pybcj-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 7.4 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3 (from py7zr->voxel51-eta~=0.12->fiftyone)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr->voxel51-eta~=0.12->fiftyone)
#   Downloading inflate64-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 14.0 MB/s eta 0:00:00
# Collecting brotli>=1.1.0 (from py7zr->voxel51-eta~=0.12->fiftyone)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 31.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->voxel51-eta~=0.12->fiftyone) (3.3.2)
# Installing collected packages: wcwidth, texttable, sseclient-py, pprintpp, kaleido, brotli, xmltodict, taskgroup, retrying, rarfile, pyzstd, pyppmd, pycryptodomex, pybcj, priority, multivolumefile, jsonlines, jmespath, inflate64, hyperframe, hpack, h11, graphql-core, ftfy, fiftyone-db, dnspython, dill, Deprecated, dacite, argcomplete, aiofiles, wsproto, strawberry-graphql, starlette, pymongo, py7zr, httpcore, h2, botocore, voxel51-eta, sse-starlette, s3transfer, motor, mongoengine, hypercorn, httpx, fiftyone-brain, universal-analytics-python3, boto3, fiftyone
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.10
#     Uninstalling wcwidth-0.2.10:
#       Successfully uninstalled wcwidth-0.2.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed Deprecated-1.2.14 aiofiles-23.2.1 argcomplete-3.1.6 boto3-1.33.4 botocore-1.33.4 brotli-1.1.0 dacite-1.7.0 dill-0.3.7 dnspython-2.4.2 fiftyone-0.22.3 fiftyone-brain-0.13.4 fiftyone-db-0.4.0 ftfy-6.1.3 graphql-core-3.2.3 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-1.0.2 httpx-0.25.2 hypercorn-0.15.0 hyperframe-6.0.1 inflate64-1.0.0 jmespath-1.0.1 jsonlines-4.0.0 kaleido-0.2.1 mongoengine-0.24.2 motor-3.3.2 multivolumefile-0.2.3 pprintpp-0.4.0 priority-2.0.0 py7zr-0.20.8 pybcj-1.0.2 pycryptodomex-3.19.0 pymongo-4.6.1 pyppmd-1.1.0 pyzstd-0.15.9 rarfile-4.1 retrying-1.3.4 s3transfer-0.8.2 sse-starlette-0.10.3 sseclient-py-1.8.0 starlette-0.32.0.post1 strawberry-graphql-0.138.1 taskgroup-0.0.0a4 texttable-1.7.0 universal-analytics-python3-1.1.1 voxel51-eta-0.12.0 wcwidth-0.2.12 wsproto-1.2.0 xmltodict-0.13.0
# Collecting fiftyone-db-ubuntu2204
#   Downloading fiftyone_db_ubuntu2204-0.4.0-py3-none-manylinux1_x86_64.whl (42.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 11.2 MB/s eta 0:00:00
# Installing collected packages: fiftyone-db-ubuntu2204
# Successfully installed fiftyone-db-ubuntu2204-0.4.0

# %%
import fiftyone as fo
import fiftyone.zoo as foz

# Load the COCO-2017 dataset
# This will download it from the FiftyOne Dataset Zoo if necessary
dataset = foz.load_zoo_dataset("coco-2017", split="train", label_types=["detections"], classes=["person"], max_samples=6000)

# Print summary information about the view
print(dataset)
# Out:
# Downloading split 'train' to '/root/fiftyone/coco-2017/train' if necessary
# INFO:fiftyone.zoo.datasets:Downloading split 'train' to '/root/fiftyone/coco-2017/train' if necessary
# Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# INFO:fiftyone.utils.coco:Found annotations at '/root/fiftyone/coco-2017/raw/instances_train2017.json'
# 100 images found; downloading the remaining 5900
# INFO:fiftyone.utils.coco:100 images found; downloading the remaining 5900
#  100% |████████████████| 5900/5900 [11.9m elapsed, 0s remaining, 8.2 images/s]
# INFO:eta.core.utils: 100% |████████████████| 5900/5900 [11.9m elapsed, 0s remaining, 8.2 images/s]
# Writing annotations for 6000 downloaded samples to '/root/fiftyone/coco-2017/train/labels.json'
# INFO:fiftyone.utils.coco:Writing annotations for 6000 downloaded samples to '/root/fiftyone/coco-2017/train/labels.json'
# Dataset info written to '/root/fiftyone/coco-2017/info.json'
# INFO:fiftyone.zoo.datasets:Dataset info written to '/root/fiftyone/coco-2017/info.json'
# Loading 'coco-2017' split 'train'
# INFO:fiftyone.zoo.datasets:Loading 'coco-2017' split 'train'
#  100% |███████████████| 6000/6000 [45.5s elapsed, 0s remaining, 128.8 samples/s]
# INFO:eta.core.utils: 100% |███████████████| 6000/6000 [45.5s elapsed, 0s remaining, 128.8 samples/s]
# Dataset 'coco-2017-train-6000' created
# INFO:fiftyone.zoo.datasets:Dataset 'coco-2017-train-6000' created
# Name:        coco-2017-train-6000
# Media type:  image
# Num samples: 6000
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:           fiftyone.core.fields.ObjectIdField
#     filepath:     fiftyone.core.fields.StringField
#     tags:         fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:     fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     ground_truth: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)

# %%
session = fo.launch_app(dataset)
# Out:
# <style>
#
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-40150758-1975-4714-bbe5-3a246a9b149c {
#   position: relative;
#   height: px;
#   display: block !important;
# }
# #foactivate-40150758-1975-4714-bbe5-3a246a9b149c {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-40150758-1975-4714-bbe5-3a246a9b149c:focus {
#   outline: none;
# }
# #fooverlay-40150758-1975-4714-bbe5-3a246a9b149c {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
# <div id="focontainer-40150758-1975-4714-bbe5-3a246a9b149c" style="display: none;">
#    <div id="fooverlay-40150758-1975-4714-bbe5-3a246a9b149c">
#       <button id="foactivate-40150758-1975-4714-bbe5-3a246a9b149c" >Activate</button>
#    </div>
# </div>
# Welcome to
#
# ███████╗██╗███████╗████████╗██╗   ██╗ ██████╗ ███╗   ██╗███████╗
# ██╔════╝██║██╔════╝╚══██╔══╝╚██╗ ██╔╝██╔═══██╗████╗  ██║██╔════╝
# █████╗  ██║█████╗     ██║    ╚████╔╝ ██║   ██║██╔██╗ ██║█████╗
# ██╔══╝  ██║██╔══╝     ██║     ╚██╔╝  ██║   ██║██║╚██╗██║██╔══╝
# ██║     ██║██║        ██║      ██║   ╚██████╔╝██║ ╚████║███████╗
# ╚═╝     ╚═╝╚═╝        ╚═╝      ╚═╝    ╚═════╝ ╚═╝  ╚═══╝╚══════╝ v0.22.3
#
# If you're finding FiftyOne helpful, here's how you can get involved:
#
# |
# |  ⭐⭐⭐ Give the project a star on GitHub ⭐⭐⭐
# |  https://github.com/voxel51/fiftyone
# |
# |  🚀🚀🚀 Join the FiftyOne Slack community 🚀🚀🚀
# |  https://slack.voxel51.com
# |
# INFO:fiftyone.core.session.session:
# Welcome to
#
# ███████╗██╗███████╗████████╗██╗   ██╗ ██████╗ ███╗   ██╗███████╗
# ██╔════╝██║██╔════╝╚══██╔══╝╚██╗ ██╔╝██╔═══██╗████╗  ██║██╔════╝
# █████╗  ██║█████╗     ██║    ╚████╔╝ ██║   ██║██╔██╗ ██║█████╗
# ██╔══╝  ██║██╔══╝     ██║     ╚██╔╝  ██║   ██║██║╚██╗██║██╔══╝
# ██║     ██║██║        ██║      ██║   ╚██████╔╝██║ ╚████║███████╗
# ╚═╝     ╚═╝╚═╝        ╚═╝      ╚═╝    ╚═════╝ ╚═╝  ╚═══╝╚══════╝ v0.22.3
#
# If you're finding FiftyOne helpful, here's how you can get involved:
#
# |
# |  ⭐⭐⭐ Give the project a star on GitHub ⭐⭐⭐
# |  https://github.com/voxel51/fiftyone
# |
# |  🚀🚀🚀 Join the FiftyOne Slack community 🚀🚀🚀
# |  https://slack.voxel51.com
# |

# %%
# Classes list
classes = dataset.distinct("ground_truth.detections.label")
print(len(classes))
classes[0:10]
# Out:
# 80
# ['airplane',
#  'apple',
#  'backpack',
#  'banana',
#  'baseball bat',
#  'baseball glove',
#  'bear',
#  'bed',
#  'bench',
#  'bicycle']

# %%
# Iterate over the dataset
for sample in dataset:
    # Get the detections
    detections = sample.ground_truth.detections
    # Filter out non-person detections
    detections = [d for d in detections if d.label == "person"]
    # Update the detections
    sample.ground_truth.detections = detections
    # Save the sample
    sample.save()

# %%
# Iterate over the dataset_test
for sample in dataset_test:
    # Get the detections
    detections = sample.ground_truth.detections
    # Filter out non-person detections
    detections = [d for d in detections if d.label == "person"]
    # Update the detections
    sample.ground_truth.detections = detections
    # Save the sample
    sample.save()

# %%
# Classes list
classes = dataset.distinct("ground_truth.detections.label")
print(len(dataset.distinct("ground_truth.detections.label")))

# %%
classes = dataset.distinct("ground_truth.detections.label")
print(len(dataset.distinct("ground_truth.detections.label")))
# Out:
# 1

# %%
len(dataset)
# Out:
# 6000

# %% [markdown]
# ## Prepare dependencies

# %%
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# !wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# Out:
# --2023-11-30 18:09:17--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23628 (23K) [text/plain]
# Saving to: ‘transforms.py’
#
# transforms.py       100%[===================>]  23.07K  --.-KB/s    in 0.001s
#
# 2023-11-30 18:09:17 (15.8 MB/s) - ‘transforms.py’ saved [23628/23628]
#
# --2023-11-30 18:09:17--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4063 (4.0K) [text/plain]
# Saving to: ‘engine.py’
#
# engine.py           100%[===================>]   3.97K  --.-KB/s    in 0s
#
# 2023-11-30 18:09:17 (65.0 MB/s) - ‘engine.py’ saved [4063/4063]
#
# --2023-11-30 18:09:17--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8388 (8.2K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   8.19K  --.-KB/s    in 0s
#
# 2023-11-30 18:09:17 (97.2 MB/s) - ‘utils.py’ saved [8388/8388]
#
# --2023-11-30 18:09:18--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6447 (6.3K) [text/plain]
# Saving to: ‘coco_eval.py’
#
# coco_eval.py        100%[===================>]   6.30K  --.-KB/s    in 0s
#
# 2023-11-30 18:09:18 (97.9 MB/s) - ‘coco_eval.py’ saved [6447/6447]
#
# --2023-11-30 18:09:18--  https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8397 (8.2K) [text/plain]
# Saving to: ‘coco_utils.py’
#
# coco_utils.py       100%[===================>]   8.20K  --.-KB/s    in 0s
#
# 2023-11-30 18:09:18 (92.9 MB/s) - ‘coco_utils.py’ saved [8397/8397]

# %% [markdown]
# ## Import dependencies

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import transforms as T
import torchvision
from engine import train_one_epoch, evaluate
import utils
import torch
import fiftyone.utils.coco as fouc

# %% [markdown]
# ## Create data loader

# %%
len(dataset.values('filepath'))
# Out:
# 6000

# %%
class ObjectDataset(torch.utils.data.Dataset):
  def __init__(self, fiftyone_dataset, transforms=None, gt_field="ground_truth", classes=None):
        self.samples = fiftyone_dataset
        self.transforms = transforms
        self.gt_field = gt_field

        self.img_paths = self.samples.values("filepath")

        self.classes = classes
        if not self.classes:
            # Get list of distinct labels that exist in the view
            self.classes = self.samples.distinct(
                "%s.detections.label" % gt_field
            )
        if self.classes[0] != "background":
            self.classes = ["background"] + self.classes

        self.labels_map_rev = {c: i for i, c in enumerate(self.classes)}

  def __getitem__(self, idx):
        img_path = self.img_paths[idx]
        sample = self.samples[img_path]
        metadata = sample.metadata
        img = Image.open(img_path).convert("RGB")

        boxes = []
        labels = []
        area = []
        iscrowd = []
        detections = sample[self.gt_field].detections
        for det in detections:
            category_id = self.labels_map_rev[det.label]
            coco_obj = fouc.COCOObject.from_label(
                det, metadata, category_id=category_id,
            )
            x, y, w, h = coco_obj.bbox
            boxes.append([x, y, x + w, y + h])
            labels.append(coco_obj.category_id)
            area.append(coco_obj.area)
            iscrowd.append(coco_obj.iscrowd)

        target = {}
        target["boxes"] = torch.as_tensor(boxes, dtype=torch.float32)
        target["labels"] = torch.as_tensor(labels, dtype=torch.int64)
        target["image_id"] = torch.as_tensor([idx])
        target["area"] = torch.as_tensor(area, dtype=torch.float32)
        target["iscrowd"] = torch.as_tensor(iscrowd, dtype=torch.int64)

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

  def __len__(self):
    return len(self.img_paths)

  def get_classes(self):
        return self.classes

# %%
from torchvision.transforms import v2 as T

def get_transform(train):
    transforms = []
    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))
    transforms.append(T.ToDtype(torch.float, scale=True))
    transforms.append(T.ToTensor())
    return T.Compose(transforms)

# %%
train_split = dataset.take(5000, seed=42)
test_split = dataset.exclude(train_split).take(1000, seed = 42)
test_split
# Out:
# Dataset:     coco-2017-train-6000
# Media type:  image
# Num samples: 1000
# Sample fields:
#     id:           fiftyone.core.fields.ObjectIdField
#     filepath:     fiftyone.core.fields.StringField
#     tags:         fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:     fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     ground_truth: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
# View stages:
#     1. Exclude(sample_ids=['6568cf6aaa0cff72eea55d17', '6568cf5baa0cff72eea50d4e', '6568cf65aa0cff72eea53e07', ...])
#     2. Take(size=1000, seed=42)

# %%
torch_dataset = ObjectDataset(train_split, get_transform(train=True))
torch_dataset_test = ObjectDataset(test_split, get_transform(train=False))
torch_dataset
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/v2/_deprecated.py:43: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.
#   warnings.warn(

# %% [markdown]
# ## Data Transform

# %% [markdown]
# ## Prepare Model

# %%
import torchvision
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator

# load a pre-trained model for classification and return
# only the features
googlenet = torchvision.models.googlenet(weights="DEFAULT")

backbone = torch.nn.Sequential(*list(googlenet.children())[:-3]) # menghilangkan fully connected layer dan global avg pool
# ``FasterRCNN`` needs to know the number of
# output channels in a backbone. For mobilenet_v2, it's 1280
# so we need to add it here
backbone.out_channels = 1024

# let's make the RPN generate 5 x 3 anchors per spatial
# location, with 5 different sizes and 3 different aspect
# ratios. We have a Tuple[Tuple[int]] because each feature
# map could potentially have different sizes and
# aspect ratios
anchor_generator = AnchorGenerator()

# let's define what are the feature maps that we will
# use to perform the region of interest cropping, as well as
# the size of the crop after rescaling.
# if your backbone returns a Tensor, featmap_names is expected to
# be [0]. More generally, the backbone should return an
# ``OrderedDict[Tensor]``, and in ``featmap_names`` you can choose which
# feature maps to use.
roi_pooler = torchvision.ops.MultiScaleRoIAlign(
    featmap_names=['0'],
    output_size=7,
    sampling_ratio=2,
)

# put the pieces together inside a Faster-RCNN model
model = FasterRCNN(
    backbone,
    num_classes=2,
    rpn_anchor_generator=anchor_generator,
    box_roi_pool=roi_pooler,
)
# Out:
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/hub/checkpoints/googlenet-1378be20.pth
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 83.0MB/s]

# %% [markdown]
# ## Train model

# %%
from engine import train_one_epoch, evaluate
import utils

def train(model, torch_dataset, torch_dataset_test, num_epochs=5):
    # train on the GPU or on the CPU, if a GPU is not available
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    print("Using device %s" % device)

    # our dataset has two classes only - background and person
    num_classes = 2

    # define training and validation data loaders
    data_loader = torch.utils.data.DataLoader(
        torch_dataset, batch_size=2, shuffle=True, num_workers=2,
        collate_fn=utils.collate_fn)

    data_loader_test = torch.utils.data.DataLoader(
        torch_dataset_test, batch_size=1, shuffle=False, num_workers=2,
        collate_fn=utils.collate_fn)

    # move model to the right device
    model.to(device)

    # construct an optimizer
    params = [p for p in model.parameters() if p.requires_grad]
    #optimizer = torch.optim.Adam(params, lr=0.0001, weight_decay=0.0005)
    # and a learning rate scheduler
    #lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                   #step_size=3,
                                                   #gamma=0.1)

    #Another version of optimizer and lr scheduler
    optimizer = torch.optim.SGD(params, lr=0.01, momentum=0.9, nesterov=True, weight_decay=1e-4)
    lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[16, 22], gamma=0.1) # lr scheduler

    # let's train it for 5 epochs
    num_epochs = 5
    hasil = []

    for epoch in range(num_epochs):
        # train for one epoch, printing every 10 iterations
        metrics_train = train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
        loss_list = metrics_train.meters.get('loss')
        hasil.append([epoch, metrics_train.meters.get('lr'), metrics_train.meters.get('loss'), metrics_train.meters.get('loss_classifier'),
                      metrics_train.meters.get('loss_box_reg'), metrics_train.meters.get('loss_objectness'), metrics_train.meters.get('loss_rpn_box_reg')])

        print("Loss_value: ", loss_list.value)
        # update the learning rate
        lr_scheduler.step()
        # evaluate on the test dataset
        hasil_eval = evaluate(model, data_loader_test, device=device)

    print("That's it!")
    torch.save(model, './Bird/point_googlenet_best.pth')
    return metrics_train, hasil, hasil_eval

def evaluate(model, data_loader, device):
    cpu_device = torch.device("cpu")
    preds = []
    targets = []
    model.eval()
    for img, target in data_loader:
        with torch.no_grad():
            pred = model([img[0].to(device)])
            pred = [{k: v.to(cpu_device) for k, v in t.items()} for t in pred]
            preds.append(pred)
            targets.append(target)

# %%
# !mkdir Bird
# Out:
# mkdir: cannot create directory ‘Bird’: File exists

# %%
metrics, hasil_train, hasil_eval = train(model, torch_dataset, torch_dataset_test, num_epochs=4)
hasil_train
# Out:
# Using device cuda
# Epoch: [0]  [   0/2500]  eta: 0:33:35  lr: 0.000020  loss: 1.5630 (1.5630)  loss_classifier: 0.7177 (0.7177)  loss_box_reg: 0.0977 (0.0977)  loss_objectness: 0.7015 (0.7015)  loss_rpn_box_reg: 0.0461 (0.0461)  time: 0.8063  data: 0.2764  max mem: 4117
# Epoch: [0]  [  10/2500]  eta: 0:16:19  lr: 0.000120  loss: 1.5875 (1.6871)  loss_classifier: 0.6854 (0.6731)  loss_box_reg: 0.0431 (0.0584)  loss_objectness: 0.6955 (0.6965)  loss_rpn_box_reg: 0.1833 (0.2590)  time: 0.3935  data: 0.0341  max mem: 4117
# Epoch: [0]  [  20/2500]  eta: 0:20:35  lr: 0.000220  loss: 1.5517 (1.5513)  loss_classifier: 0.5726 (0.5534)  loss_box_reg: 0.0526 (0.0634)  loss_objectness: 0.6902 (0.6897)  loss_rpn_box_reg: 0.1258 (0.2447)  time: 0.4829  data: 0.0162  max mem: 4664
# Epoch: [0]  [  30/2500]  eta: 0:19:25  lr: 0.000320  loss: 1.3112 (1.4931)  loss_classifier: 0.2810 (0.4451)  loss_box_reg: 0.0595 (0.0652)  loss_objectness: 0.6694 (0.6795)  loss_rpn_box_reg: 0.1818 (0.3032)  time: 0.5147  data: 0.0217  max mem: 4664
# Epoch: [0]  [  40/2500]  eta: 0:18:09  lr: 0.000420  loss: 1.0430 (1.3612)  loss_classifier: 0.1887 (0.3704)  loss_box_reg: 0.0366 (0.0613)  loss_objectness: 0.6334 (0.6631)  loss_rpn_box_reg: 0.1736 (0.2663)  time: 0.3849  data: 0.0157  max mem: 4664
# Epoch: [0]  [  50/2500]  eta: 0:17:27  lr: 0.000519  loss: 0.9406 (1.3045)  loss_classifier: 0.1130 (0.3250)  loss_box_reg: 0.0250 (0.0542)  loss_objectness: 0.6055 (0.6476)  loss_rpn_box_reg: 0.1014 (0.2777)  time: 0.3595  data: 0.0109  max mem: 4952
# Epoch: [0]  [  60/2500]  eta: 0:17:21  lr: 0.000619  loss: 0.7499 (1.2387)  loss_classifier: 0.1070 (0.2955)  loss_box_reg: 0.0183 (0.0512)  loss_objectness: 0.5582 (0.6303)  loss_rpn_box_reg: 0.0687 (0.2617)  time: 0.3941  data: 0.0140  max mem: 4952
# Epoch: [0]  [  70/2500]  eta: 0:16:59  lr: 0.000719  loss: 0.7013 (1.2031)  loss_classifier: 0.1363 (0.2741)  loss_box_reg: 0.0266 (0.0491)  loss_objectness: 0.5030 (0.6146)  loss_rpn_box_reg: 0.0592 (0.2653)  time: 0.3989  data: 0.0137  max mem: 4952
# Epoch: [0]  [  80/2500]  eta: 0:16:33  lr: 0.000819  loss: 0.7276 (1.1813)  loss_classifier: 0.1369 (0.2570)  loss_box_reg: 0.0329 (0.0475)  loss_objectness: 0.4840 (0.5997)  loss_rpn_box_reg: 0.1072 (0.2771)  time: 0.3602  data: 0.0095  max mem: 4952
# Epoch: [0]  [  90/2500]  eta: 0:16:14  lr: 0.000919  loss: 0.7158 (1.1370)  loss_classifier: 0.1220 (0.2405)  loss_box_reg: 0.0256 (0.0451)  loss_objectness: 0.4568 (0.5865)  loss_rpn_box_reg: 0.1152 (0.2649)  time: 0.3501  data: 0.0088  max mem: 4952
# Epoch: [0]  [ 100/2500]  eta: 0:16:10  lr: 0.001019  loss: 0.7001 (1.0970)  loss_classifier: 0.0957 (0.2267)  loss_box_reg: 0.0210 (0.0430)  loss_objectness: 0.4479 (0.5729)  loss_rpn_box_reg: 0.1111 (0.2544)  time: 0.3789  data: 0.0133  max mem: 4952
# Epoch: [0]  [ 110/2500]  eta: 0:15:57  lr: 0.001119  loss: 0.6731 (1.0746)  loss_classifier: 0.0886 (0.2167)  loss_box_reg: 0.0210 (0.0425)  loss_objectness: 0.4048 (0.5609)  loss_rpn_box_reg: 0.1093 (0.2546)  time: 0.3826  data: 0.0138  max mem: 4952
# Epoch: [0]  [ 120/2500]  eta: 0:15:44  lr: 0.001219  loss: 0.5881 (1.0381)  loss_classifier: 0.1042 (0.2081)  loss_box_reg: 0.0331 (0.0428)  loss_objectness: 0.3745 (0.5452)  loss_rpn_box_reg: 0.0865 (0.2419)  time: 0.3596  data: 0.0100  max mem: 4952
# Epoch: [0]  [ 130/2500]  eta: 0:15:34  lr: 0.001319  loss: 0.5932 (1.0171)  loss_classifier: 0.1139 (0.2018)  loss_box_reg: 0.0426 (0.0433)  loss_objectness: 0.3643 (0.5316)  loss_rpn_box_reg: 0.1051 (0.2404)  time: 0.3598  data: 0.0092  max mem: 4955
# Epoch: [0]  [ 140/2500]  eta: 0:15:31  lr: 0.001419  loss: 0.5932 (0.9955)  loss_classifier: 0.1144 (0.1946)  loss_box_reg: 0.0424 (0.0435)  loss_objectness: 0.3364 (0.5200)  loss_rpn_box_reg: 0.1051 (0.2374)  time: 0.3814  data: 0.0108  max mem: 4955
# Epoch: [0]  [ 150/2500]  eta: 0:15:31  lr: 0.001518  loss: 0.5236 (0.9698)  loss_classifier: 0.0769 (0.1888)  loss_box_reg: 0.0375 (0.0436)  loss_objectness: 0.2927 (0.5065)  loss_rpn_box_reg: 0.0858 (0.2310)  time: 0.4105  data: 0.0148  max mem: 4955
# Epoch: [0]  [ 160/2500]  eta: 0:15:20  lr: 0.001618  loss: 0.6512 (0.9586)  loss_classifier: 0.1039 (0.1841)  loss_box_reg: 0.0385 (0.0442)  loss_objectness: 0.3236 (0.4976)  loss_rpn_box_reg: 0.0907 (0.2327)  time: 0.3828  data: 0.0127  max mem: 4955
# Epoch: [0]  [ 170/2500]  eta: 0:15:07  lr: 0.001718  loss: 0.6512 (0.9378)  loss_classifier: 0.1068 (0.1789)  loss_box_reg: 0.0329 (0.0442)  loss_objectness: 0.3148 (0.4877)  loss_rpn_box_reg: 0.1105 (0.2271)  time: 0.3384  data: 0.0091  max mem: 4955
# Epoch: [0]  [ 180/2500]  eta: 0:15:00  lr: 0.001818  loss: 0.5269 (0.9245)  loss_classifier: 0.0938 (0.1742)  loss_box_reg: 0.0319 (0.0439)  loss_objectness: 0.2844 (0.4806)  loss_rpn_box_reg: 0.0691 (0.2259)  time: 0.3476  data: 0.0103  max mem: 4955
# Epoch: [0]  [ 190/2500]  eta: 0:15:04  lr: 0.001918  loss: 0.4781 (0.9037)  loss_classifier: 0.1051 (0.1720)  loss_box_reg: 0.0619 (0.0462)  loss_objectness: 0.2206 (0.4679)  loss_rpn_box_reg: 0.0695 (0.2177)  time: 0.4078  data: 0.0146  max mem: 4955
# Epoch: [0]  [ 200/2500]  eta: 0:14:56  lr: 0.002018  loss: 0.5295 (0.8947)  loss_classifier: 0.1209 (0.1688)  loss_box_reg: 0.0643 (0.0466)  loss_objectness: 0.2309 (0.4628)  loss_rpn_box_reg: 0.0903 (0.2165)  time: 0.4048  data: 0.0132  max mem: 4955
# Epoch: [0]  [ 210/2500]  eta: 0:14:53  lr: 0.002118  loss: 0.7697 (0.8903)  loss_classifier: 0.1009 (0.1661)  loss_box_reg: 0.0392 (0.0469)  loss_objectness: 0.3310 (0.4575)  loss_rpn_box_reg: 0.1833 (0.2198)  time: 0.3782  data: 0.0095  max mem: 4955
# Epoch: [0]  [ 220/2500]  eta: 0:14:54  lr: 0.002218  loss: 0.5592 (0.8799)  loss_classifier: 0.0999 (0.1632)  loss_box_reg: 0.0488 (0.0470)  loss_objectness: 0.2711 (0.4513)  loss_rpn_box_reg: 0.1767 (0.2185)  time: 0.4160  data: 0.0123  max mem: 4955
# Epoch: [0]  [ 230/2500]  eta: 0:14:51  lr: 0.002318  loss: 0.5085 (0.8699)  loss_classifier: 0.1010 (0.1606)  loss_box_reg: 0.0488 (0.0469)  loss_objectness: 0.2447 (0.4451)  loss_rpn_box_reg: 0.1421 (0.2173)  time: 0.4205  data: 0.0152  max mem: 4955
# Epoch: [0]  [ 240/2500]  eta: 0:14:45  lr: 0.002418  loss: 0.5750 (0.8584)  loss_classifier: 0.1010 (0.1576)  loss_box_reg: 0.0405 (0.0469)  loss_objectness: 0.2819 (0.4389)  loss_rpn_box_reg: 0.1421 (0.2150)  time: 0.3870  data: 0.0126  max mem: 4955
# Epoch: [0]  [ 250/2500]  eta: 0:14:45  lr: 0.002517  loss: 0.5419 (0.8510)  loss_classifier: 0.0969 (0.1555)  loss_box_reg: 0.0460 (0.0468)  loss_objectness: 0.2718 (0.4341)  loss_rpn_box_reg: 0.0894 (0.2145)  time: 0.4027  data: 0.0124  max mem: 4955
# Epoch: [0]  [ 260/2500]  eta: 0:14:42  lr: 0.002617  loss: 0.5419 (0.8398)  loss_classifier: 0.0969 (0.1534)  loss_box_reg: 0.0500 (0.0469)  loss_objectness: 0.2718 (0.4285)  loss_rpn_box_reg: 0.0894 (0.2111)  time: 0.4206  data: 0.0155  max mem: 4955
# Epoch: [0]  [ 270/2500]  eta: 0:14:40  lr: 0.002717  loss: 0.5490 (0.8286)  loss_classifier: 0.1063 (0.1519)  loss_box_reg: 0.0567 (0.0478)  loss_objectness: 0.2804 (0.4221)  loss_rpn_box_reg: 0.0694 (0.2069)  time: 0.4106  data: 0.0150  max mem: 4955
# Epoch: [0]  [ 280/2500]  eta: 0:14:34  lr: 0.002817  loss: 0.4976 (0.8180)  loss_classifier: 0.1070 (0.1505)  loss_box_reg: 0.0760 (0.0486)  loss_objectness: 0.2184 (0.4156)  loss_rpn_box_reg: 0.0653 (0.2032)  time: 0.3914  data: 0.0125  max mem: 4955
# Epoch: [0]  [ 290/2500]  eta: 0:14:26  lr: 0.002917  loss: 0.4301 (0.8150)  loss_classifier: 0.1070 (0.1496)  loss_box_reg: 0.0756 (0.0496)  loss_objectness: 0.2169 (0.4115)  loss_rpn_box_reg: 0.0486 (0.2042)  time: 0.3540  data: 0.0094  max mem: 4955
# Epoch: [0]  [ 300/2500]  eta: 0:14:23  lr: 0.003017  loss: 0.4741 (0.8094)  loss_classifier: 0.1011 (0.1484)  loss_box_reg: 0.0621 (0.0503)  loss_objectness: 0.2208 (0.4075)  loss_rpn_box_reg: 0.0501 (0.2031)  time: 0.3712  data: 0.0100  max mem: 4955
# Epoch: [0]  [ 310/2500]  eta: 0:14:19  lr: 0.003117  loss: 0.6157 (0.8044)  loss_classifier: 0.1002 (0.1471)  loss_box_reg: 0.0556 (0.0507)  loss_objectness: 0.2695 (0.4051)  loss_rpn_box_reg: 0.1003 (0.2015)  time: 0.3973  data: 0.0126  max mem: 4955
# Epoch: [0]  [ 320/2500]  eta: 0:14:13  lr: 0.003217  loss: 0.5922 (0.7951)  loss_classifier: 0.0975 (0.1456)  loss_box_reg: 0.0585 (0.0514)  loss_objectness: 0.2650 (0.4004)  loss_rpn_box_reg: 0.0732 (0.1977)  time: 0.3821  data: 0.0115  max mem: 4955
# Epoch: [0]  [ 330/2500]  eta: 0:14:08  lr: 0.003317  loss: 0.4962 (0.7960)  loss_classifier: 0.0975 (0.1444)  loss_box_reg: 0.0607 (0.0517)  loss_objectness: 0.2364 (0.3988)  loss_rpn_box_reg: 0.0543 (0.2010)  time: 0.3679  data: 0.0092  max mem: 4955
# Epoch: [0]  [ 340/2500]  eta: 0:14:06  lr: 0.003417  loss: 0.4755 (0.7902)  loss_classifier: 0.0908 (0.1429)  loss_box_reg: 0.0489 (0.0517)  loss_objectness: 0.2364 (0.3950)  loss_rpn_box_reg: 0.0663 (0.2006)  time: 0.3982  data: 0.0112  max mem: 4955
# Epoch: [0]  [ 350/2500]  eta: 0:14:02  lr: 0.003516  loss: 0.5283 (0.7882)  loss_classifier: 0.0908 (0.1418)  loss_box_reg: 0.0530 (0.0525)  loss_objectness: 0.2444 (0.3926)  loss_rpn_box_reg: 0.1170 (0.2013)  time: 0.4068  data: 0.0118  max mem: 4955
# Epoch: [0]  [ 360/2500]  eta: 0:13:57  lr: 0.003616  loss: 0.5346 (0.7823)  loss_classifier: 0.0999 (0.1405)  loss_box_reg: 0.0664 (0.0529)  loss_objectness: 0.2184 (0.3885)  loss_rpn_box_reg: 0.1203 (0.2004)  time: 0.3827  data: 0.0096  max mem: 4955
# Epoch: [0]  [ 370/2500]  eta: 0:13:53  lr: 0.003716  loss: 0.4482 (0.7785)  loss_classifier: 0.0969 (0.1396)  loss_box_reg: 0.0580 (0.0535)  loss_objectness: 0.2059 (0.3846)  loss_rpn_box_reg: 0.0759 (0.2008)  time: 0.3792  data: 0.0086  max mem: 4955
# Epoch: [0]  [ 380/2500]  eta: 0:13:51  lr: 0.003816  loss: 0.4523 (0.7720)  loss_classifier: 0.0827 (0.1386)  loss_box_reg: 0.0611 (0.0541)  loss_objectness: 0.1952 (0.3808)  loss_rpn_box_reg: 0.0723 (0.1985)  time: 0.4078  data: 0.0132  max mem: 4955
# Epoch: [0]  [ 390/2500]  eta: 0:13:47  lr: 0.003916  loss: 0.5910 (0.7741)  loss_classifier: 0.1087 (0.1382)  loss_box_reg: 0.0624 (0.0544)  loss_objectness: 0.2725 (0.3791)  loss_rpn_box_reg: 0.1549 (0.2025)  time: 0.4088  data: 0.0131  max mem: 4955
# Epoch: [0]  [ 400/2500]  eta: 0:13:41  lr: 0.004016  loss: 0.5915 (0.7689)  loss_classifier: 0.0984 (0.1371)  loss_box_reg: 0.0624 (0.0548)  loss_objectness: 0.2725 (0.3760)  loss_rpn_box_reg: 0.1405 (0.2010)  time: 0.3716  data: 0.0086  max mem: 4955
# Epoch: [0]  [ 410/2500]  eta: 0:13:38  lr: 0.004116  loss: 0.4192 (0.7623)  loss_classifier: 0.0849 (0.1360)  loss_box_reg: 0.0628 (0.0552)  loss_objectness: 0.2010 (0.3725)  loss_rpn_box_reg: 0.0513 (0.1985)  time: 0.3791  data: 0.0105  max mem: 4955
# Epoch: [0]  [ 420/2500]  eta: 0:13:34  lr: 0.004216  loss: 0.3718 (0.7556)  loss_classifier: 0.0843 (0.1351)  loss_box_reg: 0.0628 (0.0555)  loss_objectness: 0.1877 (0.3688)  loss_rpn_box_reg: 0.0312 (0.1962)  time: 0.3999  data: 0.0127  max mem: 4955
# Epoch: [0]  [ 430/2500]  eta: 0:13:29  lr: 0.004316  loss: 0.4475 (0.7501)  loss_classifier: 0.0843 (0.1346)  loss_box_reg: 0.0475 (0.0559)  loss_objectness: 0.2018 (0.3655)  loss_rpn_box_reg: 0.0577 (0.1941)  time: 0.3834  data: 0.0108  max mem: 4955
# Epoch: [0]  [ 440/2500]  eta: 0:13:24  lr: 0.004416  loss: 0.4051 (0.7439)  loss_classifier: 0.0816 (0.1340)  loss_box_reg: 0.0574 (0.0569)  loss_objectness: 0.1924 (0.3616)  loss_rpn_box_reg: 0.0446 (0.1913)  time: 0.3623  data: 0.0087  max mem: 4955
# Epoch: [0]  [ 450/2500]  eta: 0:13:20  lr: 0.004515  loss: 0.3896 (0.7426)  loss_classifier: 0.0979 (0.1338)  loss_box_reg: 0.0695 (0.0579)  loss_objectness: 0.1552 (0.3591)  loss_rpn_box_reg: 0.0497 (0.1919)  time: 0.3736  data: 0.0096  max mem: 4955
# Epoch: [0]  [ 460/2500]  eta: 0:13:15  lr: 0.004615  loss: 0.5123 (0.7381)  loss_classifier: 0.1243 (0.1334)  loss_box_reg: 0.0954 (0.0586)  loss_objectness: 0.1844 (0.3561)  loss_rpn_box_reg: 0.1012 (0.1899)  time: 0.3850  data: 0.0106  max mem: 4955
# Epoch: [0]  [ 470/2500]  eta: 0:13:12  lr: 0.004715  loss: 0.5541 (0.7369)  loss_classifier: 0.1094 (0.1328)  loss_box_reg: 0.0785 (0.0589)  loss_objectness: 0.2017 (0.3545)  loss_rpn_box_reg: 0.1376 (0.1906)  time: 0.3928  data: 0.0094  max mem: 4955
# Epoch: [0]  [ 480/2500]  eta: 0:13:08  lr: 0.004815  loss: 0.3663 (0.7296)  loss_classifier: 0.0761 (0.1314)  loss_box_reg: 0.0567 (0.0585)  loss_objectness: 0.1707 (0.3513)  loss_rpn_box_reg: 0.0783 (0.1886)  time: 0.3942  data: 0.0086  max mem: 4955
# Epoch: [0]  [ 490/2500]  eta: 0:13:05  lr: 0.004915  loss: 0.4250 (0.7314)  loss_classifier: 0.0761 (0.1311)  loss_box_reg: 0.0591 (0.0591)  loss_objectness: 0.2209 (0.3507)  loss_rpn_box_reg: 0.1163 (0.1905)  time: 0.3978  data: 0.0111  max mem: 4955
# Epoch: [0]  [ 500/2500]  eta: 0:13:00  lr: 0.005015  loss: 0.4250 (0.7254)  loss_classifier: 0.0792 (0.1301)  loss_box_reg: 0.0750 (0.0592)  loss_objectness: 0.2169 (0.3474)  loss_rpn_box_reg: 0.0923 (0.1887)  time: 0.3922  data: 0.0116  max mem: 4955
# Epoch: [0]  [ 510/2500]  eta: 0:12:55  lr: 0.005115  loss: 0.3858 (0.7227)  loss_classifier: 0.0789 (0.1298)  loss_box_reg: 0.0702 (0.0600)  loss_objectness: 0.1785 (0.3456)  loss_rpn_box_reg: 0.0544 (0.1874)  time: 0.3696  data: 0.0097  max mem: 4955
# Epoch: [0]  [ 520/2500]  eta: 0:12:52  lr: 0.005215  loss: 0.4188 (0.7177)  loss_classifier: 0.0795 (0.1290)  loss_box_reg: 0.0718 (0.0604)  loss_objectness: 0.1818 (0.3426)  loss_rpn_box_reg: 0.0717 (0.1857)  time: 0.3791  data: 0.0101  max mem: 4955
# Epoch: [0]  [ 530/2500]  eta: 0:12:49  lr: 0.005315  loss: 0.4955 (0.7150)  loss_classifier: 0.0801 (0.1291)  loss_box_reg: 0.0776 (0.0611)  loss_objectness: 0.1947 (0.3405)  loss_rpn_box_reg: 0.0758 (0.1842)  time: 0.4072  data: 0.0121  max mem: 4955
# Epoch: [0]  [ 540/2500]  eta: 0:12:45  lr: 0.005415  loss: 0.6522 (0.7146)  loss_classifier: 0.1411 (0.1290)  loss_box_reg: 0.0913 (0.0619)  loss_objectness: 0.2075 (0.3383)  loss_rpn_box_reg: 0.0758 (0.1854)  time: 0.4083  data: 0.0117  max mem: 4955
# Epoch: [0]  [ 550/2500]  eta: 0:12:41  lr: 0.005514  loss: 0.4530 (0.7122)  loss_classifier: 0.0879 (0.1283)  loss_box_reg: 0.0671 (0.0617)  loss_objectness: 0.2020 (0.3370)  loss_rpn_box_reg: 0.1089 (0.1853)  time: 0.3893  data: 0.0102  max mem: 4955
# Epoch: [0]  [ 560/2500]  eta: 0:12:38  lr: 0.005614  loss: 0.4530 (0.7101)  loss_classifier: 0.0768 (0.1276)  loss_box_reg: 0.0592 (0.0619)  loss_objectness: 0.2144 (0.3360)  loss_rpn_box_reg: 0.0682 (0.1846)  time: 0.3986  data: 0.0108  max mem: 4955
# Epoch: [0]  [ 570/2500]  eta: 0:12:34  lr: 0.005714  loss: 0.4407 (0.7078)  loss_classifier: 0.0898 (0.1269)  loss_box_reg: 0.0645 (0.0620)  loss_objectness: 0.2144 (0.3340)  loss_rpn_box_reg: 0.0624 (0.1850)  time: 0.4001  data: 0.0102  max mem: 4955
# Epoch: [0]  [ 580/2500]  eta: 0:12:29  lr: 0.005814  loss: 0.4407 (0.7044)  loss_classifier: 0.0879 (0.1263)  loss_box_reg: 0.0555 (0.0622)  loss_objectness: 0.1983 (0.3316)  loss_rpn_box_reg: 0.0792 (0.1843)  time: 0.3808  data: 0.0087  max mem: 4955
# Epoch: [0]  [ 590/2500]  eta: 0:12:26  lr: 0.005914  loss: 0.5119 (0.7007)  loss_classifier: 0.0862 (0.1258)  loss_box_reg: 0.0582 (0.0623)  loss_objectness: 0.1983 (0.3296)  loss_rpn_box_reg: 0.0895 (0.1830)  time: 0.3922  data: 0.0092  max mem: 4955
# Epoch: [0]  [ 600/2500]  eta: 0:12:24  lr: 0.006014  loss: 0.4920 (0.6979)  loss_classifier: 0.0886 (0.1255)  loss_box_reg: 0.0679 (0.0628)  loss_objectness: 0.2172 (0.3279)  loss_rpn_box_reg: 0.0724 (0.1817)  time: 0.4258  data: 0.0126  max mem: 4955
# Epoch: [0]  [ 610/2500]  eta: 0:12:19  lr: 0.006114  loss: 0.5015 (0.6968)  loss_classifier: 0.1100 (0.1256)  loss_box_reg: 0.0805 (0.0636)  loss_objectness: 0.2172 (0.3268)  loss_rpn_box_reg: 0.0598 (0.1808)  time: 0.4102  data: 0.0123  max mem: 4955
# Epoch: [0]  [ 620/2500]  eta: 0:12:15  lr: 0.006214  loss: 0.5345 (0.6956)  loss_classifier: 0.1047 (0.1253)  loss_box_reg: 0.0630 (0.0638)  loss_objectness: 0.2188 (0.3254)  loss_rpn_box_reg: 0.1391 (0.1811)  time: 0.3795  data: 0.0089  max mem: 4955
# Epoch: [0]  [ 630/2500]  eta: 0:12:12  lr: 0.006314  loss: 0.5345 (0.6939)  loss_classifier: 0.0878 (0.1250)  loss_box_reg: 0.0718 (0.0642)  loss_objectness: 0.2188 (0.3242)  loss_rpn_box_reg: 0.1391 (0.1806)  time: 0.3990  data: 0.0100  max mem: 4955
# Epoch: [0]  [ 640/2500]  eta: 0:12:10  lr: 0.006414  loss: 0.4732 (0.6904)  loss_classifier: 0.0859 (0.1245)  loss_box_reg: 0.0703 (0.0642)  loss_objectness: 0.1977 (0.3221)  loss_rpn_box_reg: 0.0993 (0.1796)  time: 0.4285  data: 0.0114  max mem: 4955
# Epoch: [0]  [ 650/2500]  eta: 0:12:06  lr: 0.006513  loss: 0.4732 (0.6903)  loss_classifier: 0.0710 (0.1238)  loss_box_reg: 0.0556 (0.0642)  loss_objectness: 0.1917 (0.3212)  loss_rpn_box_reg: 0.1221 (0.1810)  time: 0.4183  data: 0.0095  max mem: 4955
# Epoch: [0]  [ 660/2500]  eta: 0:12:02  lr: 0.006613  loss: 0.2940 (0.6840)  loss_classifier: 0.0628 (0.1228)  loss_box_reg: 0.0506 (0.0640)  loss_objectness: 0.1529 (0.3185)  loss_rpn_box_reg: 0.0349 (0.1787)  time: 0.3883  data: 0.0082  max mem: 4955
# Epoch: [0]  [ 670/2500]  eta: 0:11:59  lr: 0.006713  loss: 0.3069 (0.6826)  loss_classifier: 0.0641 (0.1227)  loss_box_reg: 0.0506 (0.0645)  loss_objectness: 0.1529 (0.3177)  loss_rpn_box_reg: 0.0395 (0.1777)  time: 0.4146  data: 0.0099  max mem: 4955
# Epoch: [0]  [ 680/2500]  eta: 0:11:55  lr: 0.006813  loss: 0.4663 (0.6807)  loss_classifier: 0.1079 (0.1227)  loss_box_reg: 0.0781 (0.0649)  loss_objectness: 0.1760 (0.3160)  loss_rpn_box_reg: 0.0799 (0.1770)  time: 0.4250  data: 0.0108  max mem: 4955
# Epoch: [0]  [ 690/2500]  eta: 0:11:51  lr: 0.006913  loss: 0.4663 (0.6801)  loss_classifier: 0.0837 (0.1224)  loss_box_reg: 0.0579 (0.0651)  loss_objectness: 0.1470 (0.3147)  loss_rpn_box_reg: 0.0883 (0.1781)  time: 0.3916  data: 0.0094  max mem: 4955
# Epoch: [0]  [ 700/2500]  eta: 0:11:48  lr: 0.007013  loss: 0.4554 (0.6768)  loss_classifier: 0.0840 (0.1219)  loss_box_reg: 0.0714 (0.0652)  loss_objectness: 0.1649 (0.3130)  loss_rpn_box_reg: 0.0732 (0.1767)  time: 0.3973  data: 0.0100  max mem: 4955
# Epoch: [0]  [ 710/2500]  eta: 0:11:45  lr: 0.007113  loss: 0.4479 (0.6762)  loss_classifier: 0.1007 (0.1219)  loss_box_reg: 0.0776 (0.0657)  loss_objectness: 0.1803 (0.3116)  loss_rpn_box_reg: 0.0688 (0.1769)  time: 0.4233  data: 0.0123  max mem: 4955
# Epoch: [0]  [ 720/2500]  eta: 0:11:41  lr: 0.007213  loss: 0.6021 (0.6761)  loss_classifier: 0.1377 (0.1223)  loss_box_reg: 0.0936 (0.0663)  loss_objectness: 0.1926 (0.3112)  loss_rpn_box_reg: 0.0930 (0.1763)  time: 0.4184  data: 0.0121  max mem: 4955
# Epoch: [0]  [ 730/2500]  eta: 0:11:37  lr: 0.007313  loss: 0.5294 (0.6745)  loss_classifier: 0.1292 (0.1224)  loss_box_reg: 0.0966 (0.0671)  loss_objectness: 0.2078 (0.3100)  loss_rpn_box_reg: 0.0819 (0.1750)  time: 0.3958  data: 0.0096  max mem: 4955
# Epoch: [0]  [ 740/2500]  eta: 0:11:34  lr: 0.007413  loss: 0.5114 (0.6747)  loss_classifier: 0.1224 (0.1227)  loss_box_reg: 0.1026 (0.0678)  loss_objectness: 0.2095 (0.3097)  loss_rpn_box_reg: 0.0759 (0.1745)  time: 0.4176  data: 0.0128  max mem: 4955
# Epoch: [0]  [ 750/2500]  eta: 0:11:31  lr: 0.007512  loss: 0.4476 (0.6708)  loss_classifier: 0.1031 (0.1223)  loss_box_reg: 0.0800 (0.0678)  loss_objectness: 0.1820 (0.3077)  loss_rpn_box_reg: 0.0580 (0.1730)  time: 0.4252  data: 0.0141  max mem: 4955
# Epoch: [0]  [ 760/2500]  eta: 0:11:26  lr: 0.007612  loss: 0.4189 (0.6739)  loss_classifier: 0.0955 (0.1221)  loss_box_reg: 0.0635 (0.0679)  loss_objectness: 0.1521 (0.3077)  loss_rpn_box_reg: 0.0628 (0.1762)  time: 0.3926  data: 0.0098  max mem: 4955
# Epoch: [0]  [ 770/2500]  eta: 0:11:23  lr: 0.007712  loss: 0.4382 (0.6718)  loss_classifier: 0.0830 (0.1218)  loss_box_reg: 0.0598 (0.0680)  loss_objectness: 0.2221 (0.3069)  loss_rpn_box_reg: 0.0773 (0.1750)  time: 0.4026  data: 0.0091  max mem: 4955
# Epoch: [0]  [ 780/2500]  eta: 0:11:20  lr: 0.007812  loss: 0.4375 (0.6700)  loss_classifier: 0.0978 (0.1217)  loss_box_reg: 0.0566 (0.0683)  loss_objectness: 0.1810 (0.3054)  loss_rpn_box_reg: 0.0402 (0.1745)  time: 0.4226  data: 0.0108  max mem: 4955
# Epoch: [0]  [ 790/2500]  eta: 0:11:16  lr: 0.007912  loss: 0.5671 (0.6705)  loss_classifier: 0.1125 (0.1217)  loss_box_reg: 0.0875 (0.0688)  loss_objectness: 0.1725 (0.3047)  loss_rpn_box_reg: 0.1243 (0.1754)  time: 0.4104  data: 0.0103  max mem: 4955
# Epoch: [0]  [ 800/2500]  eta: 0:11:12  lr: 0.008012  loss: 0.4770 (0.6684)  loss_classifier: 0.0887 (0.1213)  loss_box_reg: 0.0822 (0.0687)  loss_objectness: 0.1623 (0.3031)  loss_rpn_box_reg: 0.1286 (0.1753)  time: 0.3901  data: 0.0083  max mem: 4955
# Epoch: [0]  [ 810/2500]  eta: 0:11:09  lr: 0.008112  loss: 0.4770 (0.6669)  loss_classifier: 0.0670 (0.1209)  loss_box_reg: 0.0540 (0.0688)  loss_objectness: 0.1611 (0.3021)  loss_rpn_box_reg: 0.1072 (0.1751)  time: 0.4216  data: 0.0122  max mem: 4955
# Epoch: [0]  [ 820/2500]  eta: 0:11:05  lr: 0.008212  loss: 0.5016 (0.6661)  loss_classifier: 0.0803 (0.1209)  loss_box_reg: 0.0842 (0.0692)  loss_objectness: 0.1744 (0.3012)  loss_rpn_box_reg: 0.0957 (0.1748)  time: 0.4248  data: 0.0126  max mem: 4955
# Epoch: [0]  [ 830/2500]  eta: 0:11:01  lr: 0.008312  loss: 0.4208 (0.6646)  loss_classifier: 0.0803 (0.1206)  loss_box_reg: 0.0842 (0.0694)  loss_objectness: 0.1575 (0.2998)  loss_rpn_box_reg: 0.0545 (0.1747)  time: 0.3908  data: 0.0084  max mem: 4955
# Epoch: [0]  [ 840/2500]  eta: 0:10:57  lr: 0.008412  loss: 0.4355 (0.6632)  loss_classifier: 0.0740 (0.1203)  loss_box_reg: 0.0619 (0.0695)  loss_objectness: 0.1610 (0.2991)  loss_rpn_box_reg: 0.0458 (0.1743)  time: 0.4047  data: 0.0095  max mem: 4955
# Epoch: [0]  [ 850/2500]  eta: 0:10:54  lr: 0.008511  loss: 0.4355 (0.6628)  loss_classifier: 0.0878 (0.1201)  loss_box_reg: 0.0561 (0.0697)  loss_objectness: 0.1761 (0.2980)  loss_rpn_box_reg: 0.0657 (0.1751)  time: 0.4286  data: 0.0107  max mem: 4955
# Epoch: [0]  [ 860/2500]  eta: 0:10:50  lr: 0.008611  loss: 0.4164 (0.6618)  loss_classifier: 0.1045 (0.1199)  loss_box_reg: 0.0578 (0.0696)  loss_objectness: 0.1836 (0.2971)  loss_rpn_box_reg: 0.0919 (0.1752)  time: 0.4210  data: 0.0096  max mem: 4955
# Epoch: [0]  [ 870/2500]  eta: 0:10:47  lr: 0.008711  loss: 0.5457 (0.6631)  loss_classifier: 0.0994 (0.1197)  loss_box_reg: 0.0580 (0.0697)  loss_objectness: 0.1890 (0.2970)  loss_rpn_box_reg: 0.1067 (0.1768)  time: 0.4200  data: 0.0089  max mem: 4955
# Epoch: [0]  [ 880/2500]  eta: 0:10:44  lr: 0.008811  loss: 0.5910 (0.6627)  loss_classifier: 0.1013 (0.1196)  loss_box_reg: 0.0707 (0.0701)  loss_objectness: 0.2240 (0.2967)  loss_rpn_box_reg: 0.1233 (0.1763)  time: 0.4506  data: 0.0120  max mem: 4955
# Epoch: [0]  [ 890/2500]  eta: 0:10:40  lr: 0.008911  loss: 0.5645 (0.6635)  loss_classifier: 0.1013 (0.1195)  loss_box_reg: 0.0757 (0.0703)  loss_objectness: 0.2306 (0.2965)  loss_rpn_box_reg: 0.1233 (0.1772)  time: 0.4324  data: 0.0122  max mem: 4955
# Epoch: [0]  [ 900/2500]  eta: 0:10:36  lr: 0.009011  loss: 0.5645 (0.6637)  loss_classifier: 0.1077 (0.1194)  loss_box_reg: 0.0727 (0.0704)  loss_objectness: 0.2134 (0.2961)  loss_rpn_box_reg: 0.1335 (0.1778)  time: 0.4017  data: 0.0095  max mem: 4955
# Epoch: [0]  [ 910/2500]  eta: 0:10:34  lr: 0.009111  loss: 0.4891 (0.6627)  loss_classifier: 0.0721 (0.1189)  loss_box_reg: 0.0609 (0.0704)  loss_objectness: 0.2134 (0.2958)  loss_rpn_box_reg: 0.1146 (0.1777)  time: 0.4349  data: 0.0104  max mem: 4955
# Epoch: [0]  [ 920/2500]  eta: 0:10:30  lr: 0.009211  loss: 0.4440 (0.6619)  loss_classifier: 0.0679 (0.1187)  loss_box_reg: 0.0553 (0.0703)  loss_objectness: 0.2213 (0.2954)  loss_rpn_box_reg: 0.1097 (0.1775)  time: 0.4456  data: 0.0108  max mem: 4955
# Epoch: [0]  [ 930/2500]  eta: 0:10:26  lr: 0.009311  loss: 0.4425 (0.6599)  loss_classifier: 0.0720 (0.1184)  loss_box_reg: 0.0533 (0.0703)  loss_objectness: 0.2207 (0.2947)  loss_rpn_box_reg: 0.0733 (0.1764)  time: 0.4148  data: 0.0098  max mem: 4955
# Epoch: [0]  [ 940/2500]  eta: 0:10:23  lr: 0.009411  loss: 0.3848 (0.6611)  loss_classifier: 0.0627 (0.1182)  loss_box_reg: 0.0533 (0.0704)  loss_objectness: 0.1965 (0.2946)  loss_rpn_box_reg: 0.0639 (0.1778)  time: 0.4157  data: 0.0104  max mem: 4955
# Epoch: [0]  [ 950/2500]  eta: 0:10:19  lr: 0.009510  loss: 0.4938 (0.6614)  loss_classifier: 0.0745 (0.1181)  loss_box_reg: 0.0577 (0.0705)  loss_objectness: 0.2054 (0.2947)  loss_rpn_box_reg: 0.0954 (0.1781)  time: 0.4283  data: 0.0128  max mem: 4955
# Epoch: [0]  [ 960/2500]  eta: 0:10:15  lr: 0.009610  loss: 0.6143 (0.6609)  loss_classifier: 0.1090 (0.1179)  loss_box_reg: 0.0618 (0.0706)  loss_objectness: 0.2168 (0.2943)  loss_rpn_box_reg: 0.1583 (0.1780)  time: 0.4116  data: 0.0114  max mem: 4955
# Epoch: [0]  [ 970/2500]  eta: 0:10:11  lr: 0.009710  loss: 0.4858 (0.6589)  loss_classifier: 0.0759 (0.1177)  loss_box_reg: 0.0729 (0.0706)  loss_objectness: 0.2006 (0.2934)  loss_rpn_box_reg: 0.1200 (0.1772)  time: 0.4041  data: 0.0084  max mem: 4955
# Epoch: [0]  [ 980/2500]  eta: 0:10:09  lr: 0.009810  loss: 0.4102 (0.6575)  loss_classifier: 0.0759 (0.1176)  loss_box_reg: 0.0610 (0.0707)  loss_objectness: 0.1981 (0.2927)  loss_rpn_box_reg: 0.1040 (0.1764)  time: 0.4539  data: 0.0121  max mem: 4955
# Epoch: [0]  [ 990/2500]  eta: 0:10:05  lr: 0.009910  loss: 0.3754 (0.6561)  loss_classifier: 0.0819 (0.1173)  loss_box_reg: 0.0500 (0.0706)  loss_objectness: 0.1981 (0.2917)  loss_rpn_box_reg: 0.1040 (0.1765)  time: 0.4599  data: 0.0122  max mem: 5031
# Epoch: [0]  [1000/2500]  eta: 0:10:02  lr: 0.010000  loss: 0.4777 (0.6564)  loss_classifier: 0.0832 (0.1172)  loss_box_reg: 0.0548 (0.0706)  loss_objectness: 0.1946 (0.2916)  loss_rpn_box_reg: 0.1252 (0.1769)  time: 0.4263  data: 0.0095  max mem: 5031
# Epoch: [0]  [1010/2500]  eta: 0:09:58  lr: 0.010000  loss: 0.5866 (0.6573)  loss_classifier: 0.0974 (0.1173)  loss_box_reg: 0.0681 (0.0711)  loss_objectness: 0.2300 (0.2915)  loss_rpn_box_reg: 0.1531 (0.1773)  time: 0.4437  data: 0.0117  max mem: 5031
# Epoch: [0]  [1020/2500]  eta: 0:09:55  lr: 0.010000  loss: 0.6486 (0.6572)  loss_classifier: 0.1012 (0.1172)  loss_box_reg: 0.0649 (0.0711)  loss_objectness: 0.2256 (0.2909)  loss_rpn_box_reg: 0.1531 (0.1780)  time: 0.4452  data: 0.0116  max mem: 5031
# Epoch: [0]  [1030/2500]  eta: 0:09:51  lr: 0.010000  loss: 0.5344 (0.6558)  loss_classifier: 0.0950 (0.1169)  loss_box_reg: 0.0614 (0.0711)  loss_objectness: 0.1965 (0.2901)  loss_rpn_box_reg: 0.1287 (0.1776)  time: 0.4273  data: 0.0097  max mem: 5031
# Epoch: [0]  [1040/2500]  eta: 0:09:48  lr: 0.010000  loss: 0.5344 (0.6555)  loss_classifier: 0.0993 (0.1170)  loss_box_reg: 0.0893 (0.0715)  loss_objectness: 0.1795 (0.2894)  loss_rpn_box_reg: 0.1131 (0.1776)  time: 0.4505  data: 0.0107  max mem: 5031
# Epoch: [0]  [1050/2500]  eta: 0:09:45  lr: 0.010000  loss: 0.5730 (0.6543)  loss_classifier: 0.0993 (0.1169)  loss_box_reg: 0.1008 (0.0716)  loss_objectness: 0.1905 (0.2888)  loss_rpn_box_reg: 0.0834 (0.1770)  time: 0.4617  data: 0.0115  max mem: 5031
# Epoch: [0]  [1060/2500]  eta: 0:09:41  lr: 0.010000  loss: 0.3953 (0.6526)  loss_classifier: 0.0853 (0.1167)  loss_box_reg: 0.0602 (0.0718)  loss_objectness: 0.1801 (0.2879)  loss_rpn_box_reg: 0.0751 (0.1762)  time: 0.4359  data: 0.0103  max mem: 5031
# Epoch: [0]  [1070/2500]  eta: 0:09:37  lr: 0.010000  loss: 0.3953 (0.6522)  loss_classifier: 0.0767 (0.1167)  loss_box_reg: 0.0703 (0.0720)  loss_objectness: 0.1970 (0.2876)  loss_rpn_box_reg: 0.0554 (0.1759)  time: 0.4259  data: 0.0107  max mem: 5031
# Epoch: [0]  [1080/2500]  eta: 0:09:34  lr: 0.010000  loss: 0.6584 (0.6525)  loss_classifier: 0.1157 (0.1167)  loss_box_reg: 0.0711 (0.0723)  loss_objectness: 0.2071 (0.2870)  loss_rpn_box_reg: 0.1504 (0.1765)  time: 0.4477  data: 0.0121  max mem: 5031
# Epoch: [0]  [1090/2500]  eta: 0:09:30  lr: 0.010000  loss: 0.7117 (0.6539)  loss_classifier: 0.1139 (0.1166)  loss_box_reg: 0.0759 (0.0725)  loss_objectness: 0.1890 (0.2867)  loss_rpn_box_reg: 0.2162 (0.1781)  time: 0.4463  data: 0.0111  max mem: 5031
# Epoch: [0]  [1100/2500]  eta: 0:09:26  lr: 0.010000  loss: 0.4706 (0.6528)  loss_classifier: 0.1031 (0.1164)  loss_box_reg: 0.0738 (0.0725)  loss_objectness: 0.1929 (0.2863)  loss_rpn_box_reg: 0.1208 (0.1776)  time: 0.4204  data: 0.0090  max mem: 5031
# Epoch: [0]  [1110/2500]  eta: 0:09:23  lr: 0.010000  loss: 0.4390 (0.6517)  loss_classifier: 0.0901 (0.1164)  loss_box_reg: 0.1038 (0.0728)  loss_objectness: 0.1929 (0.2856)  loss_rpn_box_reg: 0.0626 (0.1768)  time: 0.4453  data: 0.0108  max mem: 5031
# Epoch: [0]  [1120/2500]  eta: 0:09:19  lr: 0.010000  loss: 0.4722 (0.6506)  loss_classifier: 0.0901 (0.1164)  loss_box_reg: 0.0899 (0.0730)  loss_objectness: 0.1696 (0.2850)  loss_rpn_box_reg: 0.0626 (0.1762)  time: 0.4535  data: 0.0115  max mem: 5031
# Epoch: [0]  [1130/2500]  eta: 0:09:15  lr: 0.010000  loss: 0.5249 (0.6499)  loss_classifier: 0.0892 (0.1162)  loss_box_reg: 0.0646 (0.0732)  loss_objectness: 0.1706 (0.2841)  loss_rpn_box_reg: 0.0983 (0.1764)  time: 0.4207  data: 0.0091  max mem: 5031
# Epoch: [0]  [1140/2500]  eta: 0:09:12  lr: 0.010000  loss: 0.5249 (0.6490)  loss_classifier: 0.0877 (0.1160)  loss_box_reg: 0.0589 (0.0733)  loss_objectness: 0.1706 (0.2835)  loss_rpn_box_reg: 0.1401 (0.1762)  time: 0.4370  data: 0.0113  max mem: 5031
# Epoch: [0]  [1150/2500]  eta: 0:09:08  lr: 0.010000  loss: 0.5170 (0.6487)  loss_classifier: 0.0847 (0.1157)  loss_box_reg: 0.0589 (0.0733)  loss_objectness: 0.1951 (0.2828)  loss_rpn_box_reg: 0.1008 (0.1769)  time: 0.4472  data: 0.0117  max mem: 5031
# Epoch: [0]  [1160/2500]  eta: 0:09:04  lr: 0.010000  loss: 0.5170 (0.6483)  loss_classifier: 0.0803 (0.1156)  loss_box_reg: 0.0647 (0.0734)  loss_objectness: 0.2059 (0.2827)  loss_rpn_box_reg: 0.1244 (0.1766)  time: 0.4253  data: 0.0089  max mem: 5031
# Epoch: [0]  [1170/2500]  eta: 0:09:01  lr: 0.010000  loss: 0.5508 (0.6491)  loss_classifier: 0.0938 (0.1155)  loss_box_reg: 0.0559 (0.0733)  loss_objectness: 0.2167 (0.2824)  loss_rpn_box_reg: 0.1862 (0.1779)  time: 0.4393  data: 0.0091  max mem: 5031
# Epoch: [0]  [1180/2500]  eta: 0:08:57  lr: 0.010000  loss: 0.5069 (0.6476)  loss_classifier: 0.0938 (0.1153)  loss_box_reg: 0.0692 (0.0734)  loss_objectness: 0.1728 (0.2815)  loss_rpn_box_reg: 0.1076 (0.1774)  time: 0.4555  data: 0.0100  max mem: 5031
# Epoch: [0]  [1190/2500]  eta: 0:08:53  lr: 0.010000  loss: 0.4547 (0.6468)  loss_classifier: 0.1071 (0.1153)  loss_box_reg: 0.0879 (0.0737)  loss_objectness: 0.1528 (0.2807)  loss_rpn_box_reg: 0.0623 (0.1771)  time: 0.4361  data: 0.0094  max mem: 5031
# Epoch: [0]  [1200/2500]  eta: 0:08:50  lr: 0.010000  loss: 0.4561 (0.6456)  loss_classifier: 0.0987 (0.1153)  loss_box_reg: 0.0785 (0.0740)  loss_objectness: 0.1663 (0.2800)  loss_rpn_box_reg: 0.0920 (0.1763)  time: 0.4375  data: 0.0096  max mem: 5031
# Epoch: [0]  [1210/2500]  eta: 0:08:46  lr: 0.010000  loss: 0.4693 (0.6456)  loss_classifier: 0.0966 (0.1153)  loss_box_reg: 0.0780 (0.0740)  loss_objectness: 0.1822 (0.2797)  loss_rpn_box_reg: 0.1229 (0.1766)  time: 0.4627  data: 0.0117  max mem: 5031
# Epoch: [0]  [1220/2500]  eta: 0:08:43  lr: 0.010000  loss: 0.5600 (0.6445)  loss_classifier: 0.0910 (0.1151)  loss_box_reg: 0.0740 (0.0742)  loss_objectness: 0.1823 (0.2789)  loss_rpn_box_reg: 0.1563 (0.1763)  time: 0.4495  data: 0.0108  max mem: 5031
# Epoch: [0]  [1230/2500]  eta: 0:08:39  lr: 0.010000  loss: 0.4692 (0.6428)  loss_classifier: 0.0890 (0.1150)  loss_box_reg: 0.0675 (0.0742)  loss_objectness: 0.1776 (0.2782)  loss_rpn_box_reg: 0.0681 (0.1755)  time: 0.4262  data: 0.0091  max mem: 5031
# Epoch: [0]  [1240/2500]  eta: 0:08:35  lr: 0.010000  loss: 0.4389 (0.6417)  loss_classifier: 0.0984 (0.1149)  loss_box_reg: 0.0767 (0.0744)  loss_objectness: 0.1826 (0.2774)  loss_rpn_box_reg: 0.0540 (0.1750)  time: 0.4588  data: 0.0113  max mem: 5148
# Epoch: [0]  [1250/2500]  eta: 0:08:32  lr: 0.010000  loss: 0.4389 (0.6409)  loss_classifier: 0.0931 (0.1149)  loss_box_reg: 0.0916 (0.0746)  loss_objectness: 0.1393 (0.2765)  loss_rpn_box_reg: 0.0614 (0.1750)  time: 0.4647  data: 0.0111  max mem: 5148
# Epoch: [0]  [1260/2500]  eta: 0:08:28  lr: 0.010000  loss: 0.4066 (0.6401)  loss_classifier: 0.0835 (0.1147)  loss_box_reg: 0.0821 (0.0747)  loss_objectness: 0.1393 (0.2761)  loss_rpn_box_reg: 0.0632 (0.1747)  time: 0.4307  data: 0.0091  max mem: 5148
# Epoch: [0]  [1270/2500]  eta: 0:08:24  lr: 0.010000  loss: 0.3940 (0.6389)  loss_classifier: 0.0760 (0.1145)  loss_box_reg: 0.0767 (0.0748)  loss_objectness: 0.1550 (0.2753)  loss_rpn_box_reg: 0.0492 (0.1743)  time: 0.4558  data: 0.0114  max mem: 5148
# Epoch: [0]  [1280/2500]  eta: 0:08:20  lr: 0.010000  loss: 0.3367 (0.6375)  loss_classifier: 0.0765 (0.1142)  loss_box_reg: 0.0655 (0.0748)  loss_objectness: 0.1525 (0.2748)  loss_rpn_box_reg: 0.0492 (0.1737)  time: 0.4651  data: 0.0110  max mem: 5148
# Epoch: [0]  [1290/2500]  eta: 0:08:16  lr: 0.010000  loss: 0.3640 (0.6367)  loss_classifier: 0.0795 (0.1141)  loss_box_reg: 0.0841 (0.0749)  loss_objectness: 0.1583 (0.2744)  loss_rpn_box_reg: 0.0927 (0.1734)  time: 0.4330  data: 0.0088  max mem: 5148
# Epoch: [0]  [1300/2500]  eta: 0:08:13  lr: 0.010000  loss: 0.4502 (0.6361)  loss_classifier: 0.0848 (0.1139)  loss_box_reg: 0.0841 (0.0749)  loss_objectness: 0.1405 (0.2738)  loss_rpn_box_reg: 0.0899 (0.1735)  time: 0.4641  data: 0.0116  max mem: 5148
# Epoch: [0]  [1310/2500]  eta: 0:08:09  lr: 0.010000  loss: 0.4405 (0.6349)  loss_classifier: 0.0897 (0.1137)  loss_box_reg: 0.0734 (0.0749)  loss_objectness: 0.1644 (0.2731)  loss_rpn_box_reg: 0.0855 (0.1731)  time: 0.4651  data: 0.0116  max mem: 5148
# Epoch: [0]  [1320/2500]  eta: 0:08:05  lr: 0.010000  loss: 0.4756 (0.6348)  loss_classifier: 0.0904 (0.1137)  loss_box_reg: 0.0857 (0.0751)  loss_objectness: 0.2031 (0.2730)  loss_rpn_box_reg: 0.0866 (0.1730)  time: 0.4221  data: 0.0087  max mem: 5148
# Epoch: [0]  [1330/2500]  eta: 0:08:02  lr: 0.010000  loss: 0.4118 (0.6333)  loss_classifier: 0.0805 (0.1135)  loss_box_reg: 0.0615 (0.0750)  loss_objectness: 0.2148 (0.2724)  loss_rpn_box_reg: 0.0705 (0.1725)  time: 0.4503  data: 0.0110  max mem: 5148
# Epoch: [0]  [1340/2500]  eta: 0:07:58  lr: 0.010000  loss: 0.3834 (0.6330)  loss_classifier: 0.0762 (0.1134)  loss_box_reg: 0.0603 (0.0751)  loss_objectness: 0.1843 (0.2720)  loss_rpn_box_reg: 0.0527 (0.1725)  time: 0.4699  data: 0.0126  max mem: 5148
# Epoch: [0]  [1350/2500]  eta: 0:07:54  lr: 0.010000  loss: 0.5180 (0.6323)  loss_classifier: 0.1008 (0.1134)  loss_box_reg: 0.0611 (0.0753)  loss_objectness: 0.1963 (0.2716)  loss_rpn_box_reg: 0.0626 (0.1721)  time: 0.4524  data: 0.0109  max mem: 5148
# Epoch: [0]  [1360/2500]  eta: 0:07:51  lr: 0.010000  loss: 0.4678 (0.6316)  loss_classifier: 0.1008 (0.1134)  loss_box_reg: 0.0770 (0.0754)  loss_objectness: 0.1966 (0.2713)  loss_rpn_box_reg: 0.0685 (0.1716)  time: 0.4698  data: 0.0118  max mem: 5148
# Epoch: [0]  [1370/2500]  eta: 0:07:47  lr: 0.010000  loss: 0.3698 (0.6307)  loss_classifier: 0.0726 (0.1133)  loss_box_reg: 0.0534 (0.0753)  loss_objectness: 0.1813 (0.2707)  loss_rpn_box_reg: 0.0843 (0.1714)  time: 0.4781  data: 0.0122  max mem: 5148
# Epoch: [0]  [1380/2500]  eta: 0:07:43  lr: 0.010000  loss: 0.3084 (0.6292)  loss_classifier: 0.0662 (0.1131)  loss_box_reg: 0.0441 (0.0752)  loss_objectness: 0.1476 (0.2699)  loss_rpn_box_reg: 0.0421 (0.1710)  time: 0.4492  data: 0.0099  max mem: 5148
# Epoch: [0]  [1390/2500]  eta: 0:07:39  lr: 0.010000  loss: 0.3410 (0.6287)  loss_classifier: 0.0752 (0.1130)  loss_box_reg: 0.0587 (0.0753)  loss_objectness: 0.1399 (0.2696)  loss_rpn_box_reg: 0.0421 (0.1708)  time: 0.4526  data: 0.0104  max mem: 5148
# Epoch: [0]  [1400/2500]  eta: 0:07:36  lr: 0.010000  loss: 0.4353 (0.6277)  loss_classifier: 0.0856 (0.1129)  loss_box_reg: 0.0725 (0.0754)  loss_objectness: 0.1683 (0.2690)  loss_rpn_box_reg: 0.0604 (0.1704)  time: 0.4805  data: 0.0122  max mem: 5148
# Epoch: [0]  [1410/2500]  eta: 0:07:32  lr: 0.010000  loss: 0.4353 (0.6269)  loss_classifier: 0.0838 (0.1129)  loss_box_reg: 0.0746 (0.0756)  loss_objectness: 0.1683 (0.2684)  loss_rpn_box_reg: 0.0590 (0.1701)  time: 0.4658  data: 0.0111  max mem: 5148
# Epoch: [0]  [1420/2500]  eta: 0:07:28  lr: 0.010000  loss: 0.5145 (0.6272)  loss_classifier: 0.1009 (0.1130)  loss_box_reg: 0.0870 (0.0759)  loss_objectness: 0.1611 (0.2683)  loss_rpn_box_reg: 0.0644 (0.1700)  time: 0.4498  data: 0.0103  max mem: 5148
# Epoch: [0]  [1430/2500]  eta: 0:07:25  lr: 0.010000  loss: 0.5145 (0.6277)  loss_classifier: 0.0984 (0.1130)  loss_box_reg: 0.0870 (0.0761)  loss_objectness: 0.1775 (0.2683)  loss_rpn_box_reg: 0.1019 (0.1704)  time: 0.4862  data: 0.0135  max mem: 5148
# Epoch: [0]  [1440/2500]  eta: 0:07:21  lr: 0.010000  loss: 0.4778 (0.6264)  loss_classifier: 0.0936 (0.1128)  loss_box_reg: 0.0788 (0.0760)  loss_objectness: 0.1698 (0.2676)  loss_rpn_box_reg: 0.1019 (0.1700)  time: 0.4825  data: 0.0135  max mem: 5148
# Epoch: [0]  [1450/2500]  eta: 0:07:17  lr: 0.010000  loss: 0.4778 (0.6259)  loss_classifier: 0.0822 (0.1127)  loss_box_reg: 0.0723 (0.0762)  loss_objectness: 0.1629 (0.2671)  loss_rpn_box_reg: 0.0741 (0.1698)  time: 0.4463  data: 0.0108  max mem: 5148
# Epoch: [0]  [1460/2500]  eta: 0:07:13  lr: 0.010000  loss: 0.5330 (0.6252)  loss_classifier: 0.0846 (0.1126)  loss_box_reg: 0.0867 (0.0763)  loss_objectness: 0.1701 (0.2666)  loss_rpn_box_reg: 0.0982 (0.1696)  time: 0.4770  data: 0.0130  max mem: 5148
# Epoch: [0]  [1470/2500]  eta: 0:07:09  lr: 0.010000  loss: 0.3500 (0.6240)  loss_classifier: 0.0699 (0.1125)  loss_box_reg: 0.0785 (0.0763)  loss_objectness: 0.1503 (0.2660)  loss_rpn_box_reg: 0.0649 (0.1692)  time: 0.4715  data: 0.0134  max mem: 5148
# Epoch: [0]  [1480/2500]  eta: 0:07:05  lr: 0.010000  loss: 0.3912 (0.6238)  loss_classifier: 0.0718 (0.1123)  loss_box_reg: 0.0487 (0.0763)  loss_objectness: 0.1529 (0.2660)  loss_rpn_box_reg: 0.0462 (0.1691)  time: 0.4220  data: 0.0105  max mem: 5148
# Epoch: [0]  [1490/2500]  eta: 0:07:01  lr: 0.010000  loss: 0.5791 (0.6237)  loss_classifier: 0.0768 (0.1124)  loss_box_reg: 0.0611 (0.0765)  loss_objectness: 0.2394 (0.2659)  loss_rpn_box_reg: 0.1018 (0.1690)  time: 0.4536  data: 0.0119  max mem: 5148
# Epoch: [0]  [1500/2500]  eta: 0:06:57  lr: 0.010000  loss: 0.5914 (0.6248)  loss_classifier: 0.0961 (0.1123)  loss_box_reg: 0.0546 (0.0765)  loss_objectness: 0.2394 (0.2661)  loss_rpn_box_reg: 0.1666 (0.1699)  time: 0.4570  data: 0.0116  max mem: 5148
# Epoch: [0]  [1510/2500]  eta: 0:06:53  lr: 0.010000  loss: 0.4394 (0.6232)  loss_classifier: 0.0701 (0.1121)  loss_box_reg: 0.0519 (0.0764)  loss_objectness: 0.1950 (0.2654)  loss_rpn_box_reg: 0.0571 (0.1692)  time: 0.4239  data: 0.0094  max mem: 5148
# Epoch: [0]  [1520/2500]  eta: 0:06:49  lr: 0.010000  loss: 0.3579 (0.6230)  loss_classifier: 0.0831 (0.1120)  loss_box_reg: 0.0594 (0.0766)  loss_objectness: 0.1575 (0.2650)  loss_rpn_box_reg: 0.0501 (0.1694)  time: 0.4449  data: 0.0112  max mem: 5148
# Epoch: [0]  [1530/2500]  eta: 0:06:45  lr: 0.010000  loss: 0.5249 (0.6225)  loss_classifier: 0.0961 (0.1121)  loss_box_reg: 0.0674 (0.0768)  loss_objectness: 0.1647 (0.2643)  loss_rpn_box_reg: 0.0692 (0.1693)  time: 0.4479  data: 0.0114  max mem: 5148
# Epoch: [0]  [1540/2500]  eta: 0:06:41  lr: 0.010000  loss: 0.5279 (0.6233)  loss_classifier: 0.0933 (0.1121)  loss_box_reg: 0.0674 (0.0769)  loss_objectness: 0.1759 (0.2642)  loss_rpn_box_reg: 0.0500 (0.1702)  time: 0.4300  data: 0.0093  max mem: 5269
# Epoch: [0]  [1550/2500]  eta: 0:06:37  lr: 0.010000  loss: 0.3938 (0.6217)  loss_classifier: 0.0809 (0.1119)  loss_box_reg: 0.0570 (0.0768)  loss_objectness: 0.1644 (0.2635)  loss_rpn_box_reg: 0.0500 (0.1695)  time: 0.4584  data: 0.0097  max mem: 5269
# Epoch: [0]  [1560/2500]  eta: 0:06:33  lr: 0.010000  loss: 0.3736 (0.6218)  loss_classifier: 0.0791 (0.1118)  loss_box_reg: 0.0460 (0.0766)  loss_objectness: 0.1533 (0.2637)  loss_rpn_box_reg: 0.0674 (0.1697)  time: 0.4702  data: 0.0108  max mem: 5269
# Epoch: [0]  [1570/2500]  eta: 0:06:29  lr: 0.010000  loss: 0.4350 (0.6205)  loss_classifier: 0.0654 (0.1114)  loss_box_reg: 0.0418 (0.0765)  loss_objectness: 0.1763 (0.2632)  loss_rpn_box_reg: 0.0854 (0.1693)  time: 0.4428  data: 0.0098  max mem: 5269
# Epoch: [0]  [1580/2500]  eta: 0:06:25  lr: 0.010000  loss: 0.3950 (0.6199)  loss_classifier: 0.0601 (0.1113)  loss_box_reg: 0.0439 (0.0765)  loss_objectness: 0.1680 (0.2629)  loss_rpn_box_reg: 0.0838 (0.1692)  time: 0.4435  data: 0.0089  max mem: 5269
# Epoch: [0]  [1590/2500]  eta: 0:06:21  lr: 0.010000  loss: 0.3451 (0.6185)  loss_classifier: 0.0711 (0.1111)  loss_box_reg: 0.0575 (0.0764)  loss_objectness: 0.1503 (0.2622)  loss_rpn_box_reg: 0.0538 (0.1689)  time: 0.4705  data: 0.0112  max mem: 5269
# Epoch: [0]  [1600/2500]  eta: 0:06:17  lr: 0.010000  loss: 0.3489 (0.6179)  loss_classifier: 0.0773 (0.1110)  loss_box_reg: 0.0715 (0.0765)  loss_objectness: 0.1584 (0.2619)  loss_rpn_box_reg: 0.0332 (0.1685)  time: 0.4560  data: 0.0110  max mem: 5269
# Epoch: [0]  [1610/2500]  eta: 0:06:13  lr: 0.010000  loss: 0.5333 (0.6181)  loss_classifier: 0.0940 (0.1110)  loss_box_reg: 0.0923 (0.0767)  loss_objectness: 0.2098 (0.2618)  loss_rpn_box_reg: 0.0655 (0.1685)  time: 0.4342  data: 0.0102  max mem: 5269
# Epoch: [0]  [1620/2500]  eta: 0:06:09  lr: 0.010000  loss: 0.5915 (0.6183)  loss_classifier: 0.1245 (0.1111)  loss_box_reg: 0.1058 (0.0770)  loss_objectness: 0.2098 (0.2617)  loss_rpn_box_reg: 0.1571 (0.1685)  time: 0.4671  data: 0.0127  max mem: 5269
# Epoch: [0]  [1630/2500]  eta: 0:06:05  lr: 0.010000  loss: 0.5964 (0.6179)  loss_classifier: 0.0946 (0.1110)  loss_box_reg: 0.0581 (0.0769)  loss_objectness: 0.1975 (0.2613)  loss_rpn_box_reg: 0.1634 (0.1686)  time: 0.4632  data: 0.0113  max mem: 5269
# Epoch: [0]  [1640/2500]  eta: 0:06:01  lr: 0.010000  loss: 0.3805 (0.6170)  loss_classifier: 0.0737 (0.1108)  loss_box_reg: 0.0553 (0.0769)  loss_objectness: 0.1770 (0.2610)  loss_rpn_box_reg: 0.0510 (0.1683)  time: 0.4320  data: 0.0095  max mem: 5269
# Epoch: [0]  [1650/2500]  eta: 0:05:57  lr: 0.010000  loss: 0.3805 (0.6159)  loss_classifier: 0.0737 (0.1108)  loss_box_reg: 0.0767 (0.0770)  loss_objectness: 0.1576 (0.2604)  loss_rpn_box_reg: 0.0510 (0.1678)  time: 0.4531  data: 0.0112  max mem: 5269
# Epoch: [0]  [1660/2500]  eta: 0:05:53  lr: 0.010000  loss: 0.4573 (0.6153)  loss_classifier: 0.0786 (0.1108)  loss_box_reg: 0.0848 (0.0772)  loss_objectness: 0.1559 (0.2600)  loss_rpn_box_reg: 0.0728 (0.1673)  time: 0.4488  data: 0.0102  max mem: 5269
# Epoch: [0]  [1670/2500]  eta: 0:05:49  lr: 0.010000  loss: 0.4914 (0.6140)  loss_classifier: 0.0760 (0.1107)  loss_box_reg: 0.0634 (0.0772)  loss_objectness: 0.1329 (0.2593)  loss_rpn_box_reg: 0.0550 (0.1669)  time: 0.4334  data: 0.0087  max mem: 5269
# Epoch: [0]  [1680/2500]  eta: 0:05:45  lr: 0.010000  loss: 0.4920 (0.6152)  loss_classifier: 0.1097 (0.1108)  loss_box_reg: 0.0668 (0.0774)  loss_objectness: 0.1557 (0.2594)  loss_rpn_box_reg: 0.1156 (0.1676)  time: 0.4917  data: 0.0130  max mem: 5269
# Epoch: [0]  [1690/2500]  eta: 0:05:41  lr: 0.010000  loss: 0.5755 (0.6153)  loss_classifier: 0.1064 (0.1107)  loss_box_reg: 0.0939 (0.0774)  loss_objectness: 0.1797 (0.2592)  loss_rpn_box_reg: 0.1009 (0.1680)  time: 0.4798  data: 0.0127  max mem: 5269
# Epoch: [0]  [1700/2500]  eta: 0:05:37  lr: 0.010000  loss: 0.3904 (0.6149)  loss_classifier: 0.0748 (0.1106)  loss_box_reg: 0.0932 (0.0775)  loss_objectness: 0.1797 (0.2588)  loss_rpn_box_reg: 0.0922 (0.1680)  time: 0.4235  data: 0.0090  max mem: 5269
# Epoch: [0]  [1710/2500]  eta: 0:05:33  lr: 0.010000  loss: 0.3502 (0.6142)  loss_classifier: 0.0859 (0.1106)  loss_box_reg: 0.0796 (0.0775)  loss_objectness: 0.1869 (0.2585)  loss_rpn_box_reg: 0.0917 (0.1675)  time: 0.4506  data: 0.0114  max mem: 5269
# Epoch: [0]  [1720/2500]  eta: 0:05:29  lr: 0.010000  loss: 0.3460 (0.6131)  loss_classifier: 0.0859 (0.1105)  loss_box_reg: 0.0497 (0.0775)  loss_objectness: 0.1594 (0.2581)  loss_rpn_box_reg: 0.0728 (0.1670)  time: 0.4627  data: 0.0119  max mem: 5269
# Epoch: [0]  [1730/2500]  eta: 0:05:25  lr: 0.010000  loss: 0.4178 (0.6132)  loss_classifier: 0.0850 (0.1104)  loss_box_reg: 0.0497 (0.0775)  loss_objectness: 0.1521 (0.2578)  loss_rpn_box_reg: 0.0939 (0.1674)  time: 0.4410  data: 0.0106  max mem: 5269
# Epoch: [0]  [1740/2500]  eta: 0:05:21  lr: 0.010000  loss: 0.4211 (0.6124)  loss_classifier: 0.0802 (0.1102)  loss_box_reg: 0.0440 (0.0775)  loss_objectness: 0.1939 (0.2575)  loss_rpn_box_reg: 0.0469 (0.1672)  time: 0.4663  data: 0.0118  max mem: 5269
# Epoch: [0]  [1750/2500]  eta: 0:05:17  lr: 0.010000  loss: 0.3624 (0.6115)  loss_classifier: 0.0660 (0.1100)  loss_box_reg: 0.0664 (0.0774)  loss_objectness: 0.1631 (0.2569)  loss_rpn_box_reg: 0.0426 (0.1671)  time: 0.4736  data: 0.0121  max mem: 5269
# Epoch: [0]  [1760/2500]  eta: 0:05:12  lr: 0.010000  loss: 0.3537 (0.6108)  loss_classifier: 0.0769 (0.1100)  loss_box_reg: 0.0728 (0.0776)  loss_objectness: 0.1514 (0.2565)  loss_rpn_box_reg: 0.0293 (0.1668)  time: 0.4361  data: 0.0104  max mem: 5269
# Epoch: [0]  [1770/2500]  eta: 0:05:08  lr: 0.010000  loss: 0.3913 (0.6106)  loss_classifier: 0.0977 (0.1102)  loss_box_reg: 0.0802 (0.0778)  loss_objectness: 0.1611 (0.2563)  loss_rpn_box_reg: 0.0338 (0.1663)  time: 0.4443  data: 0.0099  max mem: 5269
# Epoch: [0]  [1780/2500]  eta: 0:05:04  lr: 0.010000  loss: 0.3937 (0.6094)  loss_classifier: 0.0861 (0.1101)  loss_box_reg: 0.0793 (0.0779)  loss_objectness: 0.1454 (0.2558)  loss_rpn_box_reg: 0.0356 (0.1657)  time: 0.4614  data: 0.0106  max mem: 5269
# Epoch: [0]  [1790/2500]  eta: 0:05:00  lr: 0.010000  loss: 0.3471 (0.6088)  loss_classifier: 0.0768 (0.1101)  loss_box_reg: 0.0769 (0.0780)  loss_objectness: 0.1418 (0.2553)  loss_rpn_box_reg: 0.0259 (0.1654)  time: 0.4510  data: 0.0094  max mem: 5269
# Epoch: [0]  [1800/2500]  eta: 0:04:56  lr: 0.010000  loss: 0.3568 (0.6075)  loss_classifier: 0.0866 (0.1100)  loss_box_reg: 0.0820 (0.0781)  loss_objectness: 0.1394 (0.2546)  loss_rpn_box_reg: 0.0342 (0.1649)  time: 0.4425  data: 0.0085  max mem: 5269
# Epoch: [0]  [1810/2500]  eta: 0:04:52  lr: 0.010000  loss: 0.4325 (0.6083)  loss_classifier: 0.1020 (0.1101)  loss_box_reg: 0.0690 (0.0782)  loss_objectness: 0.1439 (0.2545)  loss_rpn_box_reg: 0.0647 (0.1655)  time: 0.4586  data: 0.0097  max mem: 5269
# Epoch: [0]  [1820/2500]  eta: 0:04:48  lr: 0.010000  loss: 0.4669 (0.6081)  loss_classifier: 0.0923 (0.1100)  loss_box_reg: 0.0623 (0.0782)  loss_objectness: 0.2167 (0.2545)  loss_rpn_box_reg: 0.0924 (0.1655)  time: 0.4672  data: 0.0101  max mem: 5269
# Epoch: [0]  [1830/2500]  eta: 0:04:43  lr: 0.010000  loss: 0.4101 (0.6078)  loss_classifier: 0.0859 (0.1100)  loss_box_reg: 0.0680 (0.0784)  loss_objectness: 0.1639 (0.2542)  loss_rpn_box_reg: 0.0765 (0.1652)  time: 0.4460  data: 0.0095  max mem: 5269
# Epoch: [0]  [1840/2500]  eta: 0:04:39  lr: 0.010000  loss: 0.5844 (0.6090)  loss_classifier: 0.1142 (0.1101)  loss_box_reg: 0.0985 (0.0786)  loss_objectness: 0.1753 (0.2540)  loss_rpn_box_reg: 0.1006 (0.1663)  time: 0.4571  data: 0.0117  max mem: 5269
# Epoch: [0]  [1850/2500]  eta: 0:04:35  lr: 0.010000  loss: 0.5424 (0.6085)  loss_classifier: 0.1142 (0.1101)  loss_box_reg: 0.0938 (0.0787)  loss_objectness: 0.1933 (0.2538)  loss_rpn_box_reg: 0.1006 (0.1659)  time: 0.4557  data: 0.0113  max mem: 5269
# Epoch: [0]  [1860/2500]  eta: 0:04:31  lr: 0.010000  loss: 0.4964 (0.6082)  loss_classifier: 0.1090 (0.1101)  loss_box_reg: 0.0947 (0.0789)  loss_objectness: 0.1614 (0.2535)  loss_rpn_box_reg: 0.0879 (0.1658)  time: 0.4312  data: 0.0085  max mem: 5269
# Epoch: [0]  [1870/2500]  eta: 0:04:27  lr: 0.010000  loss: 0.3776 (0.6075)  loss_classifier: 0.0978 (0.1101)  loss_box_reg: 0.1247 (0.0790)  loss_objectness: 0.1614 (0.2531)  loss_rpn_box_reg: 0.0671 (0.1652)  time: 0.4652  data: 0.0116  max mem: 5269
# Epoch: [0]  [1880/2500]  eta: 0:04:23  lr: 0.010000  loss: 0.4907 (0.6080)  loss_classifier: 0.0978 (0.1102)  loss_box_reg: 0.0929 (0.0792)  loss_objectness: 0.1823 (0.2530)  loss_rpn_box_reg: 0.0470 (0.1656)  time: 0.4633  data: 0.0118  max mem: 5269
# Epoch: [0]  [1890/2500]  eta: 0:04:19  lr: 0.010000  loss: 0.4982 (0.6074)  loss_classifier: 0.0941 (0.1101)  loss_box_reg: 0.0885 (0.0791)  loss_objectness: 0.1925 (0.2527)  loss_rpn_box_reg: 0.0943 (0.1655)  time: 0.4277  data: 0.0086  max mem: 5269
# ...
# Epoch: [3]  [1880/2500]  eta: 0:05:15  lr: 0.010000  loss: 0.5110 (0.5150)  loss_classifier: 0.0882 (0.1125)  loss_box_reg: 0.0596 (0.1134)  loss_objectness: 0.1315 (0.1534)  loss_rpn_box_reg: 0.0763 (0.1356)  time: 0.5160  data: 0.0108  max mem: 5274
# Epoch: [3]  [1890/2500]  eta: 0:05:09  lr: 0.010000  loss: 0.5789 (0.5158)  loss_classifier: 0.0964 (0.1126)  loss_box_reg: 0.1104 (0.1135)  loss_objectness: 0.1332 (0.1534)  loss_rpn_box_reg: 0.0843 (0.1362)  time: 0.5090  data: 0.0106  max mem: 5274
# Epoch: [3]  [1900/2500]  eta: 0:05:04  lr: 0.010000  loss: 0.5789 (0.5161)  loss_classifier: 0.1163 (0.1127)  loss_box_reg: 0.1114 (0.1137)  loss_objectness: 0.1211 (0.1534)  loss_rpn_box_reg: 0.0825 (0.1364)  time: 0.5030  data: 0.0104  max mem: 5274
# Epoch: [3]  [1910/2500]  eta: 0:04:59  lr: 0.010000  loss: 0.6732 (0.5167)  loss_classifier: 0.1344 (0.1130)  loss_box_reg: 0.1469 (0.1141)  loss_objectness: 0.1492 (0.1536)  loss_rpn_box_reg: 0.0596 (0.1360)  time: 0.5296  data: 0.0126  max mem: 5274
# Epoch: [3]  [1920/2500]  eta: 0:04:54  lr: 0.010000  loss: 0.6447 (0.5169)  loss_classifier: 0.1606 (0.1131)  loss_box_reg: 0.1415 (0.1143)  loss_objectness: 0.1532 (0.1535)  loss_rpn_box_reg: 0.0729 (0.1360)  time: 0.5032  data: 0.0110  max mem: 5274
# Epoch: [3]  [1930/2500]  eta: 0:04:49  lr: 0.010000  loss: 0.6192 (0.5177)  loss_classifier: 0.1449 (0.1135)  loss_box_reg: 0.1310 (0.1146)  loss_objectness: 0.1209 (0.1537)  loss_rpn_box_reg: 0.0855 (0.1360)  time: 0.5005  data: 0.0102  max mem: 5274
# Epoch: [3]  [1940/2500]  eta: 0:04:44  lr: 0.010000  loss: 0.5477 (0.5175)  loss_classifier: 0.1294 (0.1134)  loss_box_reg: 0.1271 (0.1146)  loss_objectness: 0.1111 (0.1536)  loss_rpn_box_reg: 0.0505 (0.1359)  time: 0.5099  data: 0.0113  max mem: 5274
# Epoch: [3]  [1950/2500]  eta: 0:04:39  lr: 0.010000  loss: 0.4595 (0.5177)  loss_classifier: 0.1271 (0.1135)  loss_box_reg: 0.0924 (0.1146)  loss_objectness: 0.1328 (0.1536)  loss_rpn_box_reg: 0.0671 (0.1359)  time: 0.4900  data: 0.0104  max mem: 5274
# Epoch: [3]  [1960/2500]  eta: 0:04:34  lr: 0.010000  loss: 0.4796 (0.5180)  loss_classifier: 0.1290 (0.1136)  loss_box_reg: 0.1483 (0.1148)  loss_objectness: 0.1356 (0.1535)  loss_rpn_box_reg: 0.0838 (0.1360)  time: 0.5211  data: 0.0121  max mem: 5274
# Epoch: [3]  [1970/2500]  eta: 0:04:29  lr: 0.010000  loss: 0.3065 (0.5175)  loss_classifier: 0.0913 (0.1134)  loss_box_reg: 0.0927 (0.1147)  loss_objectness: 0.0784 (0.1532)  loss_rpn_box_reg: 0.0576 (0.1363)  time: 0.5256  data: 0.0123  max mem: 5274
# Epoch: [3]  [1980/2500]  eta: 0:04:24  lr: 0.010000  loss: 0.3008 (0.5176)  loss_classifier: 0.0906 (0.1135)  loss_box_reg: 0.0927 (0.1148)  loss_objectness: 0.0811 (0.1531)  loss_rpn_box_reg: 0.0358 (0.1361)  time: 0.4927  data: 0.0098  max mem: 5274
# Epoch: [3]  [1990/2500]  eta: 0:04:19  lr: 0.010000  loss: 0.4003 (0.5173)  loss_classifier: 0.0978 (0.1134)  loss_box_reg: 0.0949 (0.1148)  loss_objectness: 0.1451 (0.1532)  loss_rpn_box_reg: 0.0446 (0.1359)  time: 0.5134  data: 0.0112  max mem: 5274
# Epoch: [3]  [2000/2500]  eta: 0:04:14  lr: 0.010000  loss: 0.3982 (0.5169)  loss_classifier: 0.0887 (0.1134)  loss_box_reg: 0.0790 (0.1146)  loss_objectness: 0.1561 (0.1532)  loss_rpn_box_reg: 0.0446 (0.1357)  time: 0.5066  data: 0.0112  max mem: 5274
# Epoch: [3]  [2010/2500]  eta: 0:04:08  lr: 0.010000  loss: 0.3714 (0.5168)  loss_classifier: 0.0891 (0.1133)  loss_box_reg: 0.0829 (0.1145)  loss_objectness: 0.1299 (0.1531)  loss_rpn_box_reg: 0.0401 (0.1359)  time: 0.4943  data: 0.0101  max mem: 5274
# Epoch: [3]  [2020/2500]  eta: 0:04:03  lr: 0.010000  loss: 0.2871 (0.5159)  loss_classifier: 0.0847 (0.1132)  loss_box_reg: 0.0527 (0.1143)  loss_objectness: 0.1116 (0.1530)  loss_rpn_box_reg: 0.0281 (0.1355)  time: 0.5294  data: 0.0120  max mem: 5274
# Epoch: [3]  [2030/2500]  eta: 0:03:58  lr: 0.010000  loss: 0.2698 (0.5154)  loss_classifier: 0.0741 (0.1131)  loss_box_reg: 0.0619 (0.1142)  loss_objectness: 0.1080 (0.1527)  loss_rpn_box_reg: 0.0281 (0.1353)  time: 0.5188  data: 0.0110  max mem: 5274
# Epoch: [3]  [2040/2500]  eta: 0:03:53  lr: 0.010000  loss: 0.3451 (0.5149)  loss_classifier: 0.0785 (0.1131)  loss_box_reg: 0.0812 (0.1142)  loss_objectness: 0.1025 (0.1526)  loss_rpn_box_reg: 0.0488 (0.1350)  time: 0.5180  data: 0.0112  max mem: 5274
# Epoch: [3]  [2050/2500]  eta: 0:03:48  lr: 0.010000  loss: 0.4787 (0.5150)  loss_classifier: 0.1097 (0.1131)  loss_box_reg: 0.0887 (0.1142)  loss_objectness: 0.1416 (0.1526)  loss_rpn_box_reg: 0.0703 (0.1349)  time: 0.5253  data: 0.0124  max mem: 5274
# Epoch: [3]  [2060/2500]  eta: 0:03:43  lr: 0.010000  loss: 0.5592 (0.5159)  loss_classifier: 0.0986 (0.1131)  loss_box_reg: 0.0887 (0.1142)  loss_objectness: 0.1554 (0.1529)  loss_rpn_box_reg: 0.0799 (0.1356)  time: 0.4983  data: 0.0105  max mem: 5274
# Epoch: [3]  [2070/2500]  eta: 0:03:38  lr: 0.010000  loss: 0.5225 (0.5163)  loss_classifier: 0.0965 (0.1132)  loss_box_reg: 0.1004 (0.1144)  loss_objectness: 0.1412 (0.1531)  loss_rpn_box_reg: 0.0723 (0.1356)  time: 0.5301  data: 0.0118  max mem: 5274
# Epoch: [3]  [2080/2500]  eta: 0:03:33  lr: 0.010000  loss: 0.3686 (0.5157)  loss_classifier: 0.0919 (0.1130)  loss_box_reg: 0.0854 (0.1142)  loss_objectness: 0.1277 (0.1530)  loss_rpn_box_reg: 0.0355 (0.1354)  time: 0.5305  data: 0.0118  max mem: 5274
# Epoch: [3]  [2090/2500]  eta: 0:03:28  lr: 0.010000  loss: 0.3927 (0.5159)  loss_classifier: 0.0921 (0.1131)  loss_box_reg: 0.0779 (0.1144)  loss_objectness: 0.1093 (0.1529)  loss_rpn_box_reg: 0.0355 (0.1355)  time: 0.4953  data: 0.0093  max mem: 5274
# Epoch: [3]  [2100/2500]  eta: 0:03:23  lr: 0.010000  loss: 0.3927 (0.5152)  loss_classifier: 0.0832 (0.1129)  loss_box_reg: 0.0817 (0.1142)  loss_objectness: 0.1098 (0.1527)  loss_rpn_box_reg: 0.0510 (0.1353)  time: 0.5306  data: 0.0113  max mem: 5274
# Epoch: [3]  [2110/2500]  eta: 0:03:18  lr: 0.010000  loss: 0.4053 (0.5160)  loss_classifier: 0.0790 (0.1130)  loss_box_reg: 0.0830 (0.1143)  loss_objectness: 0.1158 (0.1528)  loss_rpn_box_reg: 0.0766 (0.1358)  time: 0.5293  data: 0.0114  max mem: 5274
# Epoch: [3]  [2120/2500]  eta: 0:03:13  lr: 0.010000  loss: 0.4053 (0.5156)  loss_classifier: 0.1024 (0.1130)  loss_box_reg: 0.1192 (0.1143)  loss_objectness: 0.1423 (0.1527)  loss_rpn_box_reg: 0.0844 (0.1355)  time: 0.5166  data: 0.0113  max mem: 5274
# Epoch: [3]  [2130/2500]  eta: 0:03:08  lr: 0.010000  loss: 0.3950 (0.5161)  loss_classifier: 0.1024 (0.1131)  loss_box_reg: 0.1113 (0.1143)  loss_objectness: 0.1479 (0.1530)  loss_rpn_box_reg: 0.0514 (0.1358)  time: 0.5271  data: 0.0129  max mem: 5274
# Epoch: [3]  [2140/2500]  eta: 0:03:03  lr: 0.010000  loss: 0.5638 (0.5167)  loss_classifier: 0.1213 (0.1131)  loss_box_reg: 0.1102 (0.1143)  loss_objectness: 0.1731 (0.1530)  loss_rpn_box_reg: 0.0499 (0.1362)  time: 0.5092  data: 0.0112  max mem: 5274
# Epoch: [3]  [2150/2500]  eta: 0:02:58  lr: 0.010000  loss: 0.6613 (0.5175)  loss_classifier: 0.1213 (0.1132)  loss_box_reg: 0.1103 (0.1143)  loss_objectness: 0.1641 (0.1532)  loss_rpn_box_reg: 0.1312 (0.1368)  time: 0.5472  data: 0.0109  max mem: 5274
# Epoch: [3]  [2160/2500]  eta: 0:02:53  lr: 0.010000  loss: 0.4863 (0.5175)  loss_classifier: 0.1073 (0.1131)  loss_box_reg: 0.0919 (0.1142)  loss_objectness: 0.1366 (0.1534)  loss_rpn_box_reg: 0.0970 (0.1368)  time: 0.5402  data: 0.0110  max mem: 5274
# Epoch: [3]  [2170/2500]  eta: 0:02:47  lr: 0.010000  loss: 0.4252 (0.5173)  loss_classifier: 0.1046 (0.1131)  loss_box_reg: 0.0757 (0.1141)  loss_objectness: 0.1216 (0.1533)  loss_rpn_box_reg: 0.0534 (0.1368)  time: 0.4976  data: 0.0097  max mem: 5274
# Epoch: [3]  [2180/2500]  eta: 0:02:42  lr: 0.010000  loss: 0.3229 (0.5172)  loss_classifier: 0.0955 (0.1131)  loss_box_reg: 0.0757 (0.1141)  loss_objectness: 0.1267 (0.1533)  loss_rpn_box_reg: 0.0812 (0.1368)  time: 0.5228  data: 0.0125  max mem: 5274
# Epoch: [3]  [2190/2500]  eta: 0:02:37  lr: 0.010000  loss: 0.4430 (0.5174)  loss_classifier: 0.1004 (0.1131)  loss_box_reg: 0.0973 (0.1141)  loss_objectness: 0.1309 (0.1533)  loss_rpn_box_reg: 0.0812 (0.1369)  time: 0.5124  data: 0.0124  max mem: 5274
# Epoch: [3]  [2200/2500]  eta: 0:02:32  lr: 0.010000  loss: 0.5131 (0.5177)  loss_classifier: 0.1151 (0.1132)  loss_box_reg: 0.1033 (0.1143)  loss_objectness: 0.1433 (0.1535)  loss_rpn_box_reg: 0.0748 (0.1367)  time: 0.4937  data: 0.0099  max mem: 5274
# Epoch: [3]  [2210/2500]  eta: 0:02:27  lr: 0.010000  loss: 0.5126 (0.5179)  loss_classifier: 0.1156 (0.1133)  loss_box_reg: 0.1033 (0.1144)  loss_objectness: 0.1433 (0.1535)  loss_rpn_box_reg: 0.0648 (0.1367)  time: 0.5104  data: 0.0111  max mem: 5274
# Epoch: [3]  [2220/2500]  eta: 0:02:22  lr: 0.010000  loss: 0.6101 (0.5186)  loss_classifier: 0.1257 (0.1133)  loss_box_reg: 0.1363 (0.1146)  loss_objectness: 0.1350 (0.1536)  loss_rpn_box_reg: 0.0999 (0.1371)  time: 0.5095  data: 0.0102  max mem: 5274
# Epoch: [3]  [2230/2500]  eta: 0:02:17  lr: 0.010000  loss: 0.5171 (0.5187)  loss_classifier: 0.1347 (0.1133)  loss_box_reg: 0.1315 (0.1146)  loss_objectness: 0.1201 (0.1535)  loss_rpn_box_reg: 0.0999 (0.1373)  time: 0.5107  data: 0.0100  max mem: 5274
# Epoch: [3]  [2240/2500]  eta: 0:02:12  lr: 0.010000  loss: 0.4629 (0.5187)  loss_classifier: 0.1101 (0.1134)  loss_box_reg: 0.1315 (0.1148)  loss_objectness: 0.1114 (0.1534)  loss_rpn_box_reg: 0.0683 (0.1370)  time: 0.5073  data: 0.0108  max mem: 5274
# Epoch: [3]  [2250/2500]  eta: 0:02:07  lr: 0.010000  loss: 0.4123 (0.5185)  loss_classifier: 0.1101 (0.1134)  loss_box_reg: 0.1001 (0.1148)  loss_objectness: 0.1148 (0.1534)  loss_rpn_box_reg: 0.0941 (0.1370)  time: 0.4958  data: 0.0101  max mem: 5274
# Epoch: [3]  [2260/2500]  eta: 0:02:02  lr: 0.010000  loss: 0.3545 (0.5180)  loss_classifier: 0.0982 (0.1133)  loss_box_reg: 0.0784 (0.1147)  loss_objectness: 0.1143 (0.1532)  loss_rpn_box_reg: 0.0520 (0.1368)  time: 0.5262  data: 0.0113  max mem: 5274
# Epoch: [3]  [2270/2500]  eta: 0:01:57  lr: 0.010000  loss: 0.2957 (0.5178)  loss_classifier: 0.0818 (0.1133)  loss_box_reg: 0.0718 (0.1146)  loss_objectness: 0.1299 (0.1531)  loss_rpn_box_reg: 0.0250 (0.1368)  time: 0.5254  data: 0.0109  max mem: 5274
# Epoch: [3]  [2280/2500]  eta: 0:01:51  lr: 0.010000  loss: 0.3878 (0.5187)  loss_classifier: 0.0991 (0.1135)  loss_box_reg: 0.0719 (0.1147)  loss_objectness: 0.1509 (0.1535)  loss_rpn_box_reg: 0.0524 (0.1370)  time: 0.4915  data: 0.0093  max mem: 5274
# Epoch: [3]  [2290/2500]  eta: 0:01:46  lr: 0.010000  loss: 0.5518 (0.5195)  loss_classifier: 0.1367 (0.1136)  loss_box_reg: 0.1285 (0.1150)  loss_objectness: 0.1575 (0.1536)  loss_rpn_box_reg: 0.0993 (0.1373)  time: 0.5224  data: 0.0128  max mem: 5274
# Epoch: [3]  [2300/2500]  eta: 0:01:41  lr: 0.010000  loss: 0.5842 (0.5198)  loss_classifier: 0.1367 (0.1137)  loss_box_reg: 0.1386 (0.1151)  loss_objectness: 0.1449 (0.1537)  loss_rpn_box_reg: 0.0993 (0.1372)  time: 0.5287  data: 0.0123  max mem: 5274
# Epoch: [3]  [2310/2500]  eta: 0:01:36  lr: 0.010000  loss: 0.5179 (0.5198)  loss_classifier: 0.1131 (0.1137)  loss_box_reg: 0.1223 (0.1151)  loss_objectness: 0.1400 (0.1538)  loss_rpn_box_reg: 0.0987 (0.1371)  time: 0.5067  data: 0.0104  max mem: 5274
# Epoch: [3]  [2320/2500]  eta: 0:01:31  lr: 0.010000  loss: 0.4137 (0.5190)  loss_classifier: 0.1024 (0.1136)  loss_box_reg: 0.1206 (0.1150)  loss_objectness: 0.1234 (0.1536)  loss_rpn_box_reg: 0.0505 (0.1367)  time: 0.5277  data: 0.0118  max mem: 5274
# Epoch: [3]  [2330/2500]  eta: 0:01:26  lr: 0.010000  loss: 0.3729 (0.5194)  loss_classifier: 0.0948 (0.1138)  loss_box_reg: 0.0880 (0.1154)  loss_objectness: 0.1042 (0.1535)  loss_rpn_box_reg: 0.0505 (0.1366)  time: 0.5145  data: 0.0100  max mem: 5274
# Epoch: [3]  [2340/2500]  eta: 0:01:21  lr: 0.010000  loss: 0.2995 (0.5183)  loss_classifier: 0.0795 (0.1136)  loss_box_reg: 0.0781 (0.1152)  loss_objectness: 0.1026 (0.1533)  loss_rpn_box_reg: 0.0359 (0.1362)  time: 0.5176  data: 0.0118  max mem: 5274
# Epoch: [3]  [2350/2500]  eta: 0:01:16  lr: 0.010000  loss: 0.2706 (0.5181)  loss_classifier: 0.0745 (0.1136)  loss_box_reg: 0.0752 (0.1150)  loss_objectness: 0.1026 (0.1532)  loss_rpn_box_reg: 0.0328 (0.1362)  time: 0.5137  data: 0.0117  max mem: 5274
# Epoch: [3]  [2360/2500]  eta: 0:01:11  lr: 0.010000  loss: 0.3903 (0.5180)  loss_classifier: 0.1065 (0.1137)  loss_box_reg: 0.0928 (0.1151)  loss_objectness: 0.1251 (0.1532)  loss_rpn_box_reg: 0.0458 (0.1360)  time: 0.4798  data: 0.0088  max mem: 5274
# Epoch: [3]  [2370/2500]  eta: 0:01:06  lr: 0.010000  loss: 0.4024 (0.5183)  loss_classifier: 0.1260 (0.1138)  loss_box_reg: 0.1291 (0.1153)  loss_objectness: 0.1251 (0.1533)  loss_rpn_box_reg: 0.0426 (0.1358)  time: 0.5067  data: 0.0112  max mem: 5274
# Epoch: [3]  [2380/2500]  eta: 0:01:01  lr: 0.010000  loss: 0.4293 (0.5177)  loss_classifier: 0.1009 (0.1136)  loss_box_reg: 0.1039 (0.1151)  loss_objectness: 0.1233 (0.1532)  loss_rpn_box_reg: 0.0607 (0.1358)  time: 0.5156  data: 0.0109  max mem: 5274
# Epoch: [3]  [2390/2500]  eta: 0:00:56  lr: 0.010000  loss: 0.3958 (0.5179)  loss_classifier: 0.0840 (0.1136)  loss_box_reg: 0.0798 (0.1151)  loss_objectness: 0.1022 (0.1531)  loss_rpn_box_reg: 0.0607 (0.1360)  time: 0.4948  data: 0.0089  max mem: 5274
# Epoch: [3]  [2400/2500]  eta: 0:00:50  lr: 0.010000  loss: 0.3435 (0.5174)  loss_classifier: 0.0895 (0.1136)  loss_box_reg: 0.1056 (0.1152)  loss_objectness: 0.0913 (0.1529)  loss_rpn_box_reg: 0.0418 (0.1357)  time: 0.5227  data: 0.0115  max mem: 5274
# Epoch: [3]  [2410/2500]  eta: 0:00:45  lr: 0.010000  loss: 0.3221 (0.5171)  loss_classifier: 0.0876 (0.1136)  loss_box_reg: 0.1052 (0.1152)  loss_objectness: 0.0778 (0.1528)  loss_rpn_box_reg: 0.0306 (0.1356)  time: 0.5162  data: 0.0114  max mem: 5274
# Epoch: [3]  [2420/2500]  eta: 0:00:40  lr: 0.010000  loss: 0.3576 (0.5168)  loss_classifier: 0.0935 (0.1137)  loss_box_reg: 0.1203 (0.1153)  loss_objectness: 0.0816 (0.1526)  loss_rpn_box_reg: 0.0306 (0.1352)  time: 0.5018  data: 0.0096  max mem: 5274
# Epoch: [3]  [2430/2500]  eta: 0:00:35  lr: 0.010000  loss: 0.3289 (0.5167)  loss_classifier: 0.0873 (0.1137)  loss_box_reg: 0.1104 (0.1153)  loss_objectness: 0.0995 (0.1525)  loss_rpn_box_reg: 0.0365 (0.1352)  time: 0.5294  data: 0.0111  max mem: 5274
# Epoch: [3]  [2440/2500]  eta: 0:00:30  lr: 0.010000  loss: 0.3280 (0.5165)  loss_classifier: 0.0925 (0.1137)  loss_box_reg: 0.0814 (0.1154)  loss_objectness: 0.1013 (0.1524)  loss_rpn_box_reg: 0.0365 (0.1351)  time: 0.5036  data: 0.0104  max mem: 5274
# Epoch: [3]  [2450/2500]  eta: 0:00:25  lr: 0.010000  loss: 0.3477 (0.5163)  loss_classifier: 0.1020 (0.1136)  loss_box_reg: 0.0877 (0.1153)  loss_objectness: 0.1013 (0.1524)  loss_rpn_box_reg: 0.0510 (0.1351)  time: 0.4953  data: 0.0098  max mem: 5274
# Epoch: [3]  [2460/2500]  eta: 0:00:20  lr: 0.010000  loss: 0.4614 (0.5168)  loss_classifier: 0.1017 (0.1136)  loss_box_reg: 0.0946 (0.1153)  loss_objectness: 0.1584 (0.1526)  loss_rpn_box_reg: 0.0862 (0.1353)  time: 0.5039  data: 0.0099  max mem: 5274
# Epoch: [3]  [2470/2500]  eta: 0:00:15  lr: 0.010000  loss: 0.5329 (0.5169)  loss_classifier: 0.1110 (0.1136)  loss_box_reg: 0.1108 (0.1152)  loss_objectness: 0.1615 (0.1527)  loss_rpn_box_reg: 0.0691 (0.1354)  time: 0.4916  data: 0.0091  max mem: 5274
# Epoch: [3]  [2480/2500]  eta: 0:00:10  lr: 0.010000  loss: 0.4247 (0.5163)  loss_classifier: 0.0721 (0.1135)  loss_box_reg: 0.0744 (0.1150)  loss_objectness: 0.1405 (0.1527)  loss_rpn_box_reg: 0.0611 (0.1351)  time: 0.5371  data: 0.0122  max mem: 5274
# Epoch: [3]  [2490/2500]  eta: 0:00:05  lr: 0.010000  loss: 0.3294 (0.5160)  loss_classifier: 0.0669 (0.1134)  loss_box_reg: 0.0645 (0.1149)  loss_objectness: 0.1405 (0.1527)  loss_rpn_box_reg: 0.0632 (0.1350)  time: 0.5411  data: 0.0122  max mem: 5274
# Epoch: [3]  [2499/2500]  eta: 0:00:00  lr: 0.010000  loss: 0.3735 (0.5157)  loss_classifier: 0.0879 (0.1133)  loss_box_reg: 0.0645 (0.1149)  loss_objectness: 0.1144 (0.1526)  loss_rpn_box_reg: 0.0536 (0.1348)  time: 0.5023  data: 0.0089  max mem: 5274
# Epoch: [3] Total time: 0:21:13 (0.5096 s / it)
# Loss_value:  0.29978063702583313

# %%
import pandas as pd

display(pd.DataFrame(hasil_train).head(10))
# Out:
#    0         1                2                3                4  \
# 0  0  0.010000  0.8982 (0.9958)  0.1292 (0.1389)  0.0557 (0.0523)
# 1  1  0.010000  0.8464 (1.0678)  0.1497 (0.1353)  0.1105 (0.0742)
# 2  2  0.010000  0.8591 (0.9520)  0.1128 (0.1432)  0.0685 (0.0769)
# 3  3  0.010000  0.8907 (0.8851)  0.1207 (0.1323)  0.0404 (0.0745)
# 4  4  0.010000  0.9280 (0.8746)  0.1424 (0.1296)  0.1012 (0.0906)
#
#                  5                6
# 0  0.4701 (0.4854)  0.2327 (0.3193)
# 1  0.4020 (0.4467)  0.2139 (0.4115)
# 2  0.4001 (0.4129)  0.0954 (0.3190)
# 3  0.3500 (0.3582)  0.2554 (0.3201)
# 4  0.3459 (0.3265)  0.3297 (0.3279)

# %%
def convert_torch_predictions(preds, det_id, s_id, w, h, classes):
    # Convert the outputs of the torch model into a FiftyOne Detections object
    dets = []
    for bbox, label, score in zip(
        preds["boxes"].cpu().detach().numpy(),
        preds["labels"].cpu().detach().numpy(),
        preds["scores"].cpu().detach().numpy()
    ):
        # Parse prediction into FiftyOne Detection object
        x0,y0,x1,y1 = bbox
        coco_obj = fouc.COCOObject(det_id, s_id, int(label), [x0, y0, x1-x0, y1-y0])
        det = coco_obj.to_detection((w,h), classes)
        det["confidence"] = float(score)
        dets.append(det)
        det_id += 1

    detections = fo.Detections(detections=dets)

    return detections, det_id

def add_detections(model, torch_dataset, view, field_name="predictions"):
    # Run inference on a dataset and add results to FiftyOne
    torch.set_num_threads(1)
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    print("Using device %s" % device)

    model.eval()
    model.to(device)
    image_paths = torch_dataset.img_paths
    classes = torch_dataset.classes
    det_id = 0

    with fo.ProgressBar() as pb:
        for img, targets in pb(torch_dataset):
            # Get FiftyOne sample indexed by unique image filepath
            img_id = int(targets["image_id"][0])
            img_path = image_paths[img_id]
            sample = view[img_path]
            s_id = sample.id
            w = sample.metadata["width"]
            h = sample.metadata["height"]

            # Inference
            preds = model(img.unsqueeze(0).to(device))[0]

            detections, det_id = convert_torch_predictions(
                preds,
                det_id,
                s_id,
                w,
                h,
                classes,
            )

            sample[field_name] = detections
            sample.save()

add_detections(model, torch_dataset_val, val_split, field_name="predictions")
results = fo.evaluate_detections(
  val_split,
  "predictions",
  eval_key="eval",
  compute_mAP=True,
)

print(results.mAP())
# Out:
# Using device cuda
#  100% |█████████████████| 250/250 [1.1m elapsed, 0s remaining, 3.9 samples/s]
# INFO:eta.core.utils: 100% |█████████████████| 250/250 [1.1m elapsed, 0s remaining, 3.9 samples/s]
# Evaluating detections...
# INFO:fiftyone.utils.eval.detection:Evaluating detections...
#  100% |█████████████████| 250/250 [24.2s elapsed, 0s remaining, 22.2 samples/s]
# INFO:eta.core.utils: 100% |█████████████████| 250/250 [24.2s elapsed, 0s remaining, 22.2 samples/s]
# Performing IoU sweep...
# INFO:fiftyone.utils.eval.coco:Performing IoU sweep...
#  100% |█████████████████| 250/250 [9.2s elapsed, 0s remaining, 24.4 samples/s]
# INFO:eta.core.utils: 100% |█████████████████| 250/250 [9.2s elapsed, 0s remaining, 24.4 samples/s]
# 0.14890552291307554

# %%
results.mAP()
#0.14696518717739007 #Using 1000 train dataset backbone googlenet
#0.19834939895611925 #Using 2000 train dataset backbone googlenet
#0.4299589656348678 #Using pretrained fasterrcnn fpn50 coco
#0.14890552291307554 using the second param and learning rate
# Out:
# 0.19834939895611925

# %%
session.view = val_split.sort_by("eval_fp", reverse=True)

# %%
results_interclass = fo.evaluate_detections(
    val_split,
    "predictions",
    classwise=False
)

results_interclass.plot_confusion_matrix()
# Out:
# Evaluating detections...
# INFO:fiftyone.utils.eval.detection:Evaluating detections...
#  100% |█████████████████| 100/100 [2.3s elapsed, 0s remaining, 42.3 samples/s]
# INFO:eta.core.utils: 100% |█████████████████| 100/100 [2.3s elapsed, 0s remaining, 42.3 samples/s]
# /usr/local/lib/python3.10/dist-packages/fiftyone/core/plots/plotly.py:1575: UserWarning:
#
# Interactive plots are currently only supported in Jupyter notebooks. Support outside of notebooks and in Google Colab and Databricks will be included in an upcoming release. In the meantime, you can still use this plot, but note that (i) selecting data will not trigger callbacks, and (ii) you must manually call `plot.show()` to launch a new plot that reflects the current state of an attached session.
#
# See https://docs.voxel51.com/user_guide/plots.html#working-in-notebooks for more information.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ce5cb7d8-b70a-404c-87aa-41d7196f9e5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce5cb7d8-b70a-404c-87aa-41d7196f9e5f")) {                    Plotly.newPlot(                        "ce5cb7d8-b70a-404c-87aa-41d7196f9e5f",                        [{"mode":"markers","opacity":0.1,"x":[0,1,0,1],"y":[0,0,1,1],"type":"scatter","uid":"e92bdc52-39f8-43e8-8535-9b56048a5480"},{"colorscale":[[0.0,"rgb(255,245,235)"],[0.125,"rgb(254,230,206)"],[0.25,"rgb(253,208,162)"],[0.375,"rgb(253,174,107)"],[0.5,"rgb(253,141,60)"],[0.625,"rgb(241,105,19)"],[0.75,"rgb(217,72,1)"],[0.875,"rgb(166,54,3)"],[1.0,"rgb(127,39,4)"]],"hoverinfo":"skip","showscale":false,"z":[[1808,0],[769,116]],"zmax":1808,"zmin":0,"type":"heatmap","uid":"3dec4448-3c7f-49b9-a8bf-de44bd36f9bb"},{"colorbar":{"len":1,"lenmode":"fraction"},"colorscale":[[0.0,"rgb(255,245,235)"],[0.125,"rgb(254,230,206)"],[0.25,"rgb(253,208,162)"],[0.375,"rgb(253,174,107)"],[0.5,"rgb(253,141,60)"],[0.625,"rgb(241,105,19)"],[0.75,"rgb(217,72,1)"],[0.875,"rgb(166,54,3)"],[1.0,"rgb(127,39,4)"]],"hovertemplate":"\u003cb\u003ecount: %{z}\u003c\u002fb\u003e\u003cbr\u003etruth: %{y}\u003cbr\u003epredicted: %{x}\u003cextra\u003e\u003c\u002fextra\u003e","opacity":0.25,"z":[[1808,0],[769,116]],"zmax":1808,"zmin":0,"type":"heatmap","uid":"c960c789-32c0-49a6-b625-7bdabf792068"}],                        {"clickmode":"event","template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(51,51,51)"},"error_y":{"color":"rgb(51,51,51)"},"marker":{"line":{"color":"rgb(237,237,237)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"baxis":{"endlinecolor":"rgb(51,51,51)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(51,51,51)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"colorscale":[[0,"rgb(20,44,66)"],[1,"rgb(90,179,244)"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(237,237,237)","ticklen":6,"ticks":"inside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth" ...

# %%
model = foz.load_zoo_model("googlenet-imagenet-torch")
samples = dataset.take(25)

#
# Generate predictions for each sample and store the results in the
# `faster_rcnn` field of the dataset, discarding all predictions with
# confidence below 0.5
#
samples.apply_model(model, label_field="googlenet")
print(samples)

# Visualize predictions in the App
session = fo.launch_app(view=samples)

# %%
results = samples.evaluate_detections(
    "googlenet",
    gt_field="ground_truth",
    eval_key="eval",
    compute_mAP=True,
)
results.mAP()
